# %% [markdown]
# # Imports

# %%
#Library to make GUI
from tkinter import messagebox
import tkinter as tk

import requests 
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import getpass

from fuzzywuzzy import fuzz

import matplotlib.pyplot as plt 

import functions as fn

from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score 

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Get Data from Billboard to know de 100 hot songs

# %%
# Create URL
url = "https://www.billboard.com/charts/hot-100/"

# Create a request
results=requests.get(url, headers = {"Accept-Language": "en-US"})

# Result in string
#results.text

# We use BeautifulSoup to extract specific results
soup = BeautifulSoup(results.content,'html.parser')

# Show results in html mode
#print(soup.prettify())

# Strip=True => You can tell Beautiful Soup to strip whitespace from the beginning and end of each bit of text
# Try get the first name of song
soup.select('h3.c-title.a-no-trucate')[0].get_text(strip=True)

# Try get the first artist of song
soup.select('span.c-label.a-no-trucate')[0].get_text(strip=True)

# Calculate the len of our select
len_songs = len(soup.select('h3.c-title.a-no-trucate'))

# Create variables to store results
song = []
artist = []

# Create a for to pick the 100 best songs
for x in range(len_songs):
    song.append(soup.select('h3.c-title.a-no-trucate')[x].get_text(strip=True))
    artist.append(soup.select('span.c-label.a-no-trucate')[x].get_text(strip=True))
    
# Import pandas to create a data frame
top = pd.DataFrame({'Song':song, 'Artist':artist})
#top

# Import numpy to add a Rank
top['Rank'] = np.arange(len(top))+1
top
# Out:
#                                Song  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                           abcdefu
# 3                        Easy On Me
# 4                     Super Gremlin
# ..                              ...
# 95                           Closer
# 96                    Cold December
# 97                Get Into It (Yuh)
# 98  All Too Well (Taylor's Version)
# 99            Give Heaven Some Hell
#
#                                                Artist  Rank
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...     1
# 1                                       Glass Animals     2
# 2                                               GAYLE     3
# 3                                               Adele     4
# 4                                         Kodak Black     5
# ..                                                ...   ...
# 95                          Saweetie Featuring H.E.R.    96
# 96                                           Rod Wave    97
# 97                                           Doja Cat    98
# 98                                       Taylor Swift    99
# 99                                              HARDY   100
#
# [100 rows x 3 columns]

# %% [markdown]
# # Get playlist from Spotify to analice audio features

# %%
# Get usser and pass
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))

# Create a conexion
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Get random playlist
playlist = sp.user_playlist_tracks("Spotify","37i9dQZF1DX4WYpdgoIcn6")
playlist
# Out:
# client_id?········
# client_secret?········
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7okSU80WTrn4LXlyXYbX3P'},
#        'href': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P',
#        'id': '7okSU80WTrn4LXlyXYbX3P',
#        'name': 'Clinton Kane',
#        'type': 'artist',
#        'uri': 'spotify:artist:7okSU80WTrn4LXlyXYbX3P'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56meo2KJ9tRlaGUHSGfTpP'},
#      'href': 'https://api.spotify.com/v1/albums/56meo2KJ9tRlaGUHSGfTpP',
#      'id': '56meo2KJ9tRlaGUHSGfTpP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ff62d5125efd086e3c23dfb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ff62d5125efd086e3c23dfb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ff62d5125efd086e3c23dfb',
#        'width': 64}],
#      'name': "I GUESS I'M IN LOVE",
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:56meo2KJ9tRlaGUHSGfTpP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7okSU80WTrn4LXlyXYbX3P'},
#       'href': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P',
#       'id': '7okSU80WTrn4LXlyXYbX3P',
#       'name': 'Clinton Kane',
#       'type': 'artist',
#       'uri': 'spotify:artist:7okSU80WTrn4LXlyXYbX3P'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12104467'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1is8gU4RVcN4J8xItxWoOY'},
#     'href': 'https://api.spotify.com/v1/tracks/1is8gU4RVcN4J8xItxWoOY',
#     'id': '1is8gU4RVcN4J8xItxWoOY',
#     'is_local': False,
#     'name': "I GUESS I'M IN LOVE",
#     'popularity': 87,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cf41c8b3268141df27b6a252f0b4ea72f6453901?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1is8gU4RVcN4J8xItxWoOY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bqxdqvUtPWZri43cKHac8'},
#        'href': 'https://api.spotify.com/v1/artists/1bqxdqvUtPWZri43cKHac8',
#        'id': '1bqxdqvUtPWZri43cKHac8',
#        'name': 'MAX',
#        'type': 'artist',
#        'uri': 'spotify:artist:1bqxdqvUtPWZri43cKHac8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#        'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#        'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#        'name': 'Ali Gatie',
#        'type': 'artist',
#        'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4TENiEyNNnHbRixbSa0XKg'},
#      'href': 'https://api.spotify.com/v1/albums/4TENiEyNNnHbRixbSa0XKg',
#      'id': '4TENiEyNNnHbRixbSa0XKg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b7c878bdc17d023295df222',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b7c878bdc17d023295df222',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b7c878bdc17d023295df222',
#        'width': 64}],
#      'name': 'Butterflies',
#      'release_date': '2021-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4TENiEyNNnHbRixbSa0XKg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bqxdqvUtPWZri43cKHac8'},
#       'href': 'https://api.spotify.com/v1/artists/1bqxdqvUtPWZri43cKHac8',
#       'id': '1bqxdqvUtPWZri43cKHac8',
#       'name': 'MAX',
#       'type': 'artist',
#       'uri': 'spotify:artist:1bqxdqvUtPWZri43cKHac8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#       'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#       'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#       'name': 'Ali Gatie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 191250,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12101365'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7eQHxigpuDJjCG50JyzU8v'},
#     'href': 'https://api.spotify.com/v1/tracks/7eQHxigpuDJjCG50JyzU8v',
#     'id': '7eQHxigpuDJjCG50JyzU8v',
#     'is_local': False,
#     'name': 'Butterflies',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f22a6a785f71592ee7e099c4c0596bc4a115e735?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7eQHxigpuDJjCG50JyzU8v'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Xoteh7uEpea4TohMxjtaq'},
#      'href': 'https://api.spotify.com/v1/albums/2Xoteh7uEpea4TohMxjtaq',
#      'id': '2Xoteh7uEpea4TohMxjtaq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27333b8541201f1ef38941024be',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0233b8541201f1ef38941024be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485133b8541201f1ef38941024be',
#        'width': 64}],
#      'name': 'evermore',
#      'release_date': '2020-12-11',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2Xoteh7uEpea4TohMxjtaq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 214706,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12004699'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0lx2cLdOt3piJbcaXIV74f'},
#     'href': 'https://api.spotify.com/v1/tracks/0lx2cLdOt3piJbcaXIV74f',
#     'id': '0lx2cLdOt3piJbcaXIV74f',
#     'is_local': False,
#     'name': 'willow',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0lx2cLdOt3piJbcaXIV74f'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#        'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#        'id': '4dpARuHxo51G3z768sgnrY',
#        'name': 'Adele',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/224jZ4sUX7OhAuMwaxp86S'},
#      'href': 'https://api.spotify.com/v1/albums/224jZ4sUX7OhAuMwaxp86S',
#      'id': '224jZ4sUX7OhAuMwaxp86S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350dba34377a595e35f81b0e4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250dba34377a595e35f81b0e4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150dba34377a595e35f81b0e4',
#        'width': 64}],
#      'name': 'Easy On Me',
#      'release_date': '2021-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:224jZ4sUX7OhAuMwaxp86S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 224694,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12105970'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0gplL1WMoJ6iYaPgMCL0gX'},
#     'href': 'https://api.spotify.com/v1/tracks/0gplL1WMoJ6iYaPgMCL0gX',
#     'id': '0gplL1WMoJ6iYaPgMCL0gX',
#     'is_local': False,
#     'name': 'Easy On Me',
#     'popularity': 95,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c5014be1aeb2ab5f129e2789eff3ea87ecd5027f?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0gplL1WMoJ6iYaPgMCL0gX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AVfmawzu83sp94QW7CEGm'},
#        'href': 'https://api.spotify.com/v1/artists/3AVfmawzu83sp94QW7CEGm',
#        'id': '3AVfmawzu83sp94QW7CEGm',
#        'name': 'Astrid S',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AVfmawzu83sp94QW7CEGm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2C91kmyDRWZdm0wR8dK1Wn'},
#      'href': 'https://api.spotify.com/v1/albums/2C91kmyDRWZdm0wR8dK1Wn',
#      'id': '2C91kmyDRWZdm0wR8dK1Wn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d7ef0f772d6506524ade7fd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d7ef0f772d6506524ade7fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d7ef0f772d6506524ade7fd',
#        'width': 64}],
#      'name': "It's Ok If You Forget Me",
#      'release_date': '2020-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2C91kmyDRWZdm0wR8dK1Wn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AVfmawzu83sp94QW7CEGm'},
#       'href': 'https://api.spotify.com/v1/artists/3AVfmawzu83sp94QW7CEGm',
#       'id': '3AVfmawzu83sp94QW7CEGm',
#       'name': 'Astrid S',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AVfmawzu83sp94QW7CEGm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204989,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NOUM72000369'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/312zSwwbPU7C3sTmro4Wx9'},
#     'href': 'https://api.spotify.com/v1/tracks/312zSwwbPU7C3sTmro4Wx9',
#     'id': '312zSwwbPU7C3sTmro4Wx9',
#     'is_local': False,
#     'name': "It's Ok If You Forget Me",
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:312zSwwbPU7C3sTmro4Wx9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#        'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#        'id': '3gIRvgZssIb9aiirIg0nI3',
#        'name': 'Jeremy Zucker',
#        'type': 'artist',
#        'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#        'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#        'id': '5JMLG56F1X5mFmWNmS0iAp',
#        'name': 'Chelsea Cutler',
#        'type': 'artist',
#        'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nAv0lNEyaR9IC0RR2UQiW'},
#      'href': 'https://api.spotify.com/v1/albums/5nAv0lNEyaR9IC0RR2UQiW',
#      'id': '5nAv0lNEyaR9IC0RR2UQiW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dccb079c492cf99e02e3255b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dccb079c492cf99e02e3255b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dccb079c492cf99e02e3255b',
#        'width': 64}],
#      'name': 'this is how you fall in love',
#      'release_date': '2021-01-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5nAv0lNEyaR9IC0RR2UQiW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#       'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#       'id': '3gIRvgZssIb9aiirIg0nI3',
#       'name': 'Jeremy Zucker',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#       'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#       'id': '5JMLG56F1X5mFmWNmS0iAp',
#       'name': 'Chelsea Cutler',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 174586,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72024519'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0742PcMPo2Akmo4vHC29VZ'},
#     'href': 'https://api.spotify.com/v1/tracks/0742PcMPo2Akmo4vHC29VZ',
#     'id': '0742PcMPo2Akmo4vHC29VZ',
#     'is_local': False,
#     'name': 'this is how you fall in love',
#     'popularity': 4,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0742PcMPo2Akmo4vHC29VZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#        'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#        'id': '49tQo2QULno7gxHutgccqF',
#        'name': 'LANY',
#        'type': 'artist',
#        'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3fHkjpHZjohpdtiJJdVtez'},
#      'href': 'https://api.spotify.com/v1/albums/3fHkjpHZjohpdtiJJdVtez',
#      'id': '3fHkjpHZjohpdtiJJdVtez',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344bdc09715b571735ac35b2d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244bdc09715b571735ac35b2d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144bdc09715b571735ac35b2d',
#        'width': 64}],
#      'name': 'dancing in the kitchen',
#      'release_date': '2021-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3fHkjpHZjohpdtiJJdVtez'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#       'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#       'id': '49tQo2QULno7gxHutgccqF',
#       'name': 'LANY',
#       'type': 'artist',
#       'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 208599,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72103516'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ohcCrxZkBfFbkuRPOZQZX'},
#     'href': 'https://api.spotify.com/v1/tracks/0ohcCrxZkBfFbkuRPOZQZX',
#     'id': '0ohcCrxZkBfFbkuRPOZQZX',
#     'is_local': False,
#     'name': 'dancing in the kitchen',
#     'popularity': 76,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ohcCrxZkBfFbkuRPOZQZX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#        'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#        'id': '7n2wHs1TKAczGzO7Dd2rGr',
#        'name': 'Shawn Mendes',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3sDud6BapENewYxlL8VH8r'},
#      'href': 'https://api.spotify.com/v1/albums/3sDud6BapENewYxlL8VH8r',
#      'id': '3sDud6BapENewYxlL8VH8r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27372355b30dde4b6ded10ef48c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0272355b30dde4b6ded10ef48c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485172355b30dde4b6ded10ef48c',
#        'width': 64}],
#      'name': "It'll Be Okay",
#      'release_date': '2021-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3sDud6BapENewYxlL8VH8r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
# ...
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7zbaDQ3uGL5GyIyeUVkktz'},
#      'href': 'https://api.spotify.com/v1/albums/7zbaDQ3uGL5GyIyeUVkktz',
#      'id': '7zbaDQ3uGL5GyIyeUVkktz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27363ba168dece1f7815898090b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0263ba168dece1f7815898090b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485163ba168dece1f7815898090b',
#        'width': 64}],
#      'name': 'Feels (feat. Khalid)',
#      'release_date': '2021-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7zbaDQ3uGL5GyIyeUVkktz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4B3aifxHtpcKHuNi12lmSt'},
#       'href': 'https://api.spotify.com/v1/artists/4B3aifxHtpcKHuNi12lmSt',
#       'id': '4B3aifxHtpcKHuNi12lmSt',
#       'name': 'WATTS',
#       'type': 'artist',
#       'uri': 'spotify:artist:4B3aifxHtpcKHuNi12lmSt'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#       'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#       'id': '6LuN9FCkKOj5PcnpouEgny',
#       'name': 'Khalid',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 221974,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC12100506'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LZ9FO9UsGIcTKbShnfNsG'},
#     'href': 'https://api.spotify.com/v1/tracks/6LZ9FO9UsGIcTKbShnfNsG',
#     'id': '6LZ9FO9UsGIcTKbShnfNsG',
#     'is_local': False,
#     'name': 'Feels (feat. Khalid)',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/85de802396a0c3b805a4c2f41e7f4b7e72ebc078?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6LZ9FO9UsGIcTKbShnfNsG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0fA0VVWsXO9YnASrzqfmYu'},
#        'href': 'https://api.spotify.com/v1/artists/0fA0VVWsXO9YnASrzqfmYu',
#        'id': '0fA0VVWsXO9YnASrzqfmYu',
#        'name': 'Kid Cudi',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fA0VVWsXO9YnASrzqfmYu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1geA7d12ed5LXsBns7ONB4'},
#      'href': 'https://api.spotify.com/v1/albums/1geA7d12ed5LXsBns7ONB4',
#      'id': '1geA7d12ed5LXsBns7ONB4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739675cabe34ef4cc14556ea35',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029675cabe34ef4cc14556ea35',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519675cabe34ef4cc14556ea35',
#        'width': 64}],
#      'name': 'Just Look Up (From Don’t Look Up)',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1geA7d12ed5LXsBns7ONB4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0fA0VVWsXO9YnASrzqfmYu'},
#       'href': 'https://api.spotify.com/v1/artists/0fA0VVWsXO9YnASrzqfmYu',
#       'id': '0fA0VVWsXO9YnASrzqfmYu',
#       'name': 'Kid Cudi',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fA0VVWsXO9YnASrzqfmYu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 201667,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72121498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3QPBocWfIcOCdFFvmqn60F'},
#     'href': 'https://api.spotify.com/v1/tracks/3QPBocWfIcOCdFFvmqn60F',
#     'id': '3QPBocWfIcOCdFFvmqn60F',
#     'is_local': False,
#     'name': 'Just Look Up (From Don’t Look Up)',
#     'popularity': 78,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3QPBocWfIcOCdFFvmqn60F'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-02-24T23:02:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#        'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#        'id': '04gDigrS5kc9YWfZHwBETP',
#        'name': 'Maroon 5',
#        'type': 'artist',
#        'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'}],
#      'available_markets': ['KR'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2cDt5R89HP8ZCXhNAmZs27'},
#      'href': 'https://api.spotify.com/v1/albums/2cDt5R89HP8ZCXhNAmZs27',
#      'id': '2cDt5R89HP8ZCXhNAmZs27',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273839deab240b73a3c76bf51eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02839deab240b73a3c76bf51eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851839deab240b73a3c76bf51eb',
#        'width': 64}],
#      'name': "Nobody's Love",
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2cDt5R89HP8ZCXhNAmZs27'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#       'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#       'id': '04gDigrS5kc9YWfZHwBETP',
#       'name': 'Maroon 5',
#       'type': 'artist',
#       'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'}],
#     'available_markets': ['KR'],
#     'disc_number': 1,
#     'duration_ms': 211253,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72013111'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3kwgqoBqTwoAH4nT29TYrq'},
#     'href': 'https://api.spotify.com/v1/tracks/3kwgqoBqTwoAH4nT29TYrq',
#     'id': '3kwgqoBqTwoAH4nT29TYrq',
#     'is_local': False,
#     'name': "Nobody's Love",
#     'popularity': 21,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3kwgqoBqTwoAH4nT29TYrq'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 130}

# %%
#dictionary comprehension 
list_info = {
  track["track"]["id"]: [track["track"]["name"], 
  track["track"]["artists"][0]["name"]] 
  for track in playlist["items"]
}
list_info
# Out:
# {'1is8gU4RVcN4J8xItxWoOY': ["I GUESS I'M IN LOVE", 'Clinton Kane'],
#  '7eQHxigpuDJjCG50JyzU8v': ['Butterflies', 'MAX'],
#  '0lx2cLdOt3piJbcaXIV74f': ['willow', 'Taylor Swift'],
#  '0gplL1WMoJ6iYaPgMCL0gX': ['Easy On Me', 'Adele'],
#  '312zSwwbPU7C3sTmro4Wx9': ["It's Ok If You Forget Me", 'Astrid S'],
#  '0742PcMPo2Akmo4vHC29VZ': ['this is how you fall in love', 'Jeremy Zucker'],
#  '0ohcCrxZkBfFbkuRPOZQZX': ['dancing in the kitchen', 'LANY'],
#  '2KnLkZ3z7PO3kgVGHGqDpD': ["It'll Be Okay", 'Shawn Mendes'],
#  '5WtfUKzXircvW8l5aaVZWT': ['What A Time (feat. Niall Horan)',
#   'Julia Michaels'],
#  '7lPN2DXiMsVn7XUKtOW1CS': ['drivers license', 'Olivia Rodrigo'],
#  '4IQkfUsrwXol38VV3U7t7T': ['Run (feat. Ed Sheeran) (Taylor’s Version) (From The Vault)',
#   'Taylor Swift'],
#  '6OcCk1dbAb7XNHsC098oEM': ['I Quit Drinking', 'Kelsea Ballerini'],
#  '1nYzjrdVQ8RpF93M0jPFW7': ['Remember That Night?', 'Sara Kays'],
#  '6GH4tLwGW6HliKbZBdt6hD': ['Unlearn (with Gracie Abrams)', 'benny blanco'],
#  '2h9TDNEXRhcDIV3fsoEVq9': ['What Other People Say', 'Sam Fischer'],
#  '2URXzpbSUwOjltvpgtzXua': ['You Will Be Found (with Summer Walker) - From The “Dear Evan Hansen” Original Motion Picture Soundtrack',
#   'Sam Smith'],
#  '4cGqn0E8JCSY9gQllQj4Mf': ['Let Somebody Go', 'Coldplay'],
#  '135Lf4Q0CzlMNfOxbEUsLH': ['GHOST TOWN', 'Benson Boone'],
#  '727Z2S2mtNH46CbP9EWPwY': ['If You Love Her', 'Forest Blakk'],
#  '2Z8yfpFX0ZMavHkcIeHiO1': ['Monster (Shawn Mendes & Justin Bieber)',
#   'Shawn Mendes'],
#  '6N1K5OVVCopBjGViHs2IvP': ['The Joker And The Queen (feat. Taylor Swift)',
#   'Ed Sheeran'],
#  '1EHUQesfVKwbthtNcpBi9g': ['WITHOUT YOU (with Miley Cyrus)', 'The Kid LAROI'],
#  '1ZMiCix7XSAbfAJlEZWMCp': ['Falling', 'Harry Styles'],
#  '31sSFHIe4NaxltVFOEIcTa': ['working', 'Tate McRae'],
#  '6s86N7LVaJZuU4alwKp6XO': ['Are you happy?', 'SHY Martin'],
#  '58qX77t2VWMWcycsh9zKLc': ["i don't want to watch the world end with someone else",
#   'Clinton Kane'],
#  '136J2Jkg8sG7P5wilO9P1R': ['Meant To Be', 'Ber'],
#  '5GzgEC6pWf1USZsCtkG8yC': ['Paper Planes', 'Elina'],
#  '44V6EzbUSYgyfsNiP0FrlA': ['Visiting Hours', 'Ed Sheeran'],
#  '3IpYb4BekvsgmZKwI2ZDu0': ['colorblind', 'Mokita'],
#  '61Emqg95O9zo1GNOcyxq4Y': ['For Tonight', 'Giveon'],
#  '1bd4heB3yXc5iFTPoOMPuo': ['slower', 'Tate McRae'],
#  '3H3r2nKWa3Yk5gt8xgmsEt': ['This City', 'Sam Fischer'],
#  '2J4DpqJCIuuM9WjtWHbjvd': ['Grey', "Why Don't We"],
#  '68z9t6zihQgqzBGtexjTRG': ['Happy For You', 'Lukas Graham'],
#  '0ri0Han4IRJhzvERHOZTMr': ['At My Worst', 'Pink Sweat$'],
#  '6TbkMxKZudkP6Sty7rkLU9': ['Perfectly Imperfect', 'Declan J Donovan'],
#  '2EBnvom1dTybtm75a3Xh1T': ['feel like shit', 'Tate McRae'],
#  '15OCqNPYoLziEAsbVnqRj5': ['Good Without', 'Mimi Webb'],
#  '4pvb0WLRcMtbPGmtejJJ6y': ['exile (feat. Bon Iver)', 'Taylor Swift'],
#  '5u1n1kITHCxxp8twBcZxWy': ['Holy (feat. Chance The Rapper)', 'Justin Bieber'],
#  '3z1DnGBH2uhlDekJr0YVzQ': ['Best Days', 'Alessia Cara'],
#  '2kJwzbxV2ppxnQoYw4GLBZ': ['If the World Was Ending (feat. Julia Michaels)',
#   'JP Saxe'],
#  '2GjQ5KNXggsIRpx5ZUj2zX': ['Her', 'Anne-Marie'],
#  '5QYnNhTKsN3kE7OaqILA1U': ['First Times', 'Ed Sheeran'],
#  '45Q6RNX1yeHpGZpR0RjpKI': ['Lost', 'Blake Rose'],
#  '18XlJEroUwFo0tLZxscgXE': ['Lost', 'Maroon 5'],
#  '45bE4HXI0AwGZXfZtMp8JR': ['you broke me first', 'Tate McRae'],
#  '4y4spB9m0Q6026KfkAvy9Q': ['Lonely (with benny blanco)', 'Justin Bieber'],
#  '54fT5TBqwmJKn6NmJR5VKe': ['the author', 'Luz'],
#  '0E4Y1XIbs8GrAT1YqVy6dq': ['Afterglow', 'Ed Sheeran'],
#  '0awuNCj9gwJEM0seER22DW': ['CHICKEN TENDIES', 'Clinton Kane'],
#  '2gA74HvN6NKFrhgzpd5oNE': ['Line By Line (feat. Maren Morris)', 'JP Saxe'],
#  '7rq1zCf90CnU7OalBLIgNp': ['r u ok', 'Tate McRae'],
#  '7GLBqDKAJLCLIsj2GEDkSw': ['nobody else', 'LANY'],
#  '6c7N5N7amAOpeMykjlovjI': ['Walked Through Hell', 'Anson Seabra'],
#  '4Gt2kh3QbAGU6yquOWn4aW': ['Fake', 'Lauv'],
#  '2HnfqILzgKt1CepTlU4oqq': ['Like No One Does', 'Jake Scott'],
#  '5CZ40GBx1sQ9agT82CLQCT': ['traitor', 'Olivia Rodrigo'],
#  '1Ia95g66IhlAJ3qVI4qI8W': ['Slow', 'SHY Martin'],
#  '6CDzDgIUqeDY5g8ujExx2f': ['Heat Waves', 'Glass Animals'],
#  '5inDa3sWj8zqJBOdj7Bjqc': ['Hey Stupid, I Love You', 'JP Saxe'],
#  '4HBZA5flZLE435QTztThqH': ['Stuck with U (with Justin Bieber)',
#   'Ariana Grande'],
#  '0hqJxaNkPQ3sPm1tvfPlAe': ['Cry with you', 'Jeremy Zucker'],
#  '6sHxpnCerm9M6A5zaFFNfs': ['Gone', 'Blake Rose'],
#  '19pChrR4hwdINqoOFUo2Hj': ['Keep Your Head Up Princess', 'Anson Seabra'],
#  '04NMWz4ctkuILV6mUR2iWp': ['Lie', 'Sasha Alex Sloan'],
#  '0QdePZJfBpRIBautuT4FSx': ['Angels Like You', 'Miley Cyrus'],
#  '2CIYemjFXdmCWpJnfbtrD6': ['New Normal', 'Khalid'],
#  '0Kjkp9SLw8uhBAiSrSgdcB': ['Forever Young', 'Boy In Space'],
#  '5HBDBBr5OV90lubqW8ctJF': ['if we never met', 'John K'],
#  '00cBcYOlnHoXX9ver3cmdE': ['A Little Bit Yours', 'JP Saxe'],
#  '55vsJO4tLZQ37qzD5QUOmh': ['House With No Mirrors', 'Sasha Alex Sloan'],
#  '5FNS5Vj69AhRGJWjhrAd01': ['Slow Dance (feat. Ava Max)', 'AJ Mitchell'],
#  '3zjw3EZfvgjuR4AQhVlNq7': ['Lovely', 'Fly By Midnight'],
#  '1tUdd0dSQ5ij2XiqlWhlHX': ['Good Stuff', 'Griff'],
#  '5z8uLrYMcUVvzTV28twt44': ['Slow Grenade', 'Ellie Goulding'],
#  '7ce20yLkzuXXLUhzIDoZih': ['Before You Go', 'Lewis Capaldi'],
#  '3w1P8nwsVi9vxrGvxYLzAC': ['Hope Is A Heartache', 'LÉON'],
#  '2769RhOZs0ezRncRW1vryp': ['Till Forever Falls Apart', 'Ashe'],
#  '0ClPIeT6MSgfSgQ9ZrJbAq': ['Cheating on You', 'Charlie Puth'],
#  '2tSDwInMbSGmUySTeUgO5e': ['Love Like That', 'Lauv'],
#  '034KyQEk7IhbLtniVhBErj': ['17', 'Pink Sweat$'],
#  '47EWMOElkkbMp5m9SBkx7d': ['IDK You Yet', 'Alexander 23'],
#  '1LdS1ULS9e18oW3M2C1MUj': ["always, i'll care", 'Jeremy Zucker'],
#  '5kcvBnt6DPX3AMEsCx1qDh': ['Happiest Year', 'Jaymes Young'],
#  '4f9IfFvBFm7Gsf1IVEudyf': ['lie to me', 'Tate McRae'],
#  '4P6g8wuXeR3wznFk7WnI4w': ['Losing Me', 'Gabrielle Aplin'],
#  '2Ms8MDDtYBw7M3K5F3EqPX': ['Dumb Love', 'Mimi Webb'],
#  '5ovVcYo2MvjVydFwFyaaqy': ['I Should Probably Go To Bed', 'Dan + Shay'],
#  '0E6uWutxRjIDhleURR92do': ['cowboy in LA', 'LANY'],
#  '1Srt81FTalOhRw7t7l8Yh8': ['Tattoos Together', 'Lauv'],
#  '7l97ElWmIdVHWUaOeeU5ZC': ['that way', 'Tate McRae'],
#  '5RfrZ5Lgr3fdtgnvhh3va8': ["Can't Let You Go", 'Ali Gatie'],
#  '4SHJLxcRicQyT42jG95Y5u': ['No Right To Love You', 'Rhys Lewis'],
#  '3Z8FwOEN59mRMxDCtb8N0A': ['Be Kind (with Halsey)', 'Marshmello'],
#  '3ZBeHiRJUj1vdiU8zzGPgb': ['WYD Now?', 'Sadie Jean'],
#  '6LZ9FO9UsGIcTKbShnfNsG': ['Feels (feat. Khalid)', 'WATTS'],
#  '3QPBocWfIcOCdFFvmqn60F': ['Just Look Up (From Don’t Look Up)',
#   'Ariana Grande'],
#  '3kwgqoBqTwoAH4nT29TYrq': ["Nobody's Love", 'Maroon 5']}

# %%
# As we have limit 100, need do while to get all songs of the play list
# While playlist have next we can get new data
def get_tracks(playlist):
    tracks = playlist['items']
    while playlist['next']:
        playlist = sp.next(playlist)
        tracks.extend(playlist['items'])
    return tracks
first_results = get_tracks(playlist)

# get track list with url uri or ID for each track - ID in this case
audio_feats = []
for x in range(len(first_results)):
    audio_feats.extend(sp.audio_features(tracks=first_results[x]['track']['id']))

# Transform in to Dataframe
data = pd.DataFrame(audio_feats)
data
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.422   0.340    0    -6.577     1       0.0351        0.8770
# 1           0.700   0.613   11    -4.041     1       0.0408        0.3850
# 2           0.392   0.574    7    -9.195     1       0.1700        0.8330
# 3           0.604   0.366    5    -7.519     1       0.0282        0.5780
# 4           0.562   0.379    6    -7.625     1       0.2310        0.5260
# ..            ...     ...  ...       ...   ...          ...           ...
# 125         0.775   0.410    3    -7.481     1       0.0464        0.7240
# 126         0.634   0.285    9   -14.007     0       0.0807        0.9370
# 127         0.614   0.647    0    -4.681     0       0.0524        0.0687
# 128         0.517   0.435    9    -7.532     1       0.0278        0.4000
# 129         0.691   0.474   10    -8.742     0       0.0583        0.5690
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000018    0.1490    0.223   77.213  audio_features
# 1            0.000000    0.0887    0.420   88.084  audio_features
# 2            0.001790    0.1450    0.529   81.112  audio_features
# 3            0.000000    0.1330    0.130  141.981  audio_features
# 4            0.000000    0.1510    0.258  171.848  audio_features
# ..                ...       ...      ...      ...             ...
# 125          0.000026    0.1140    0.298  117.165  audio_features
# 126          0.000359    0.2320    0.203  129.650  audio_features
# 127          0.000000    0.1040    0.368  163.862  audio_features
# 128          0.000000    0.1230    0.335   97.931  audio_features
# 129          0.000626    0.0990    0.381  143.783  audio_features
#
#                          id                                   uri  \
# 0    1is8gU4RVcN4J8xItxWoOY  spotify:track:1is8gU4RVcN4J8xItxWoOY
# 1    7eQHxigpuDJjCG50JyzU8v  spotify:track:7eQHxigpuDJjCG50JyzU8v
# 2    0lx2cLdOt3piJbcaXIV74f  spotify:track:0lx2cLdOt3piJbcaXIV74f
# 3    0gplL1WMoJ6iYaPgMCL0gX  spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# 4    312zSwwbPU7C3sTmro4Wx9  spotify:track:312zSwwbPU7C3sTmro4Wx9
# ..                      ...                                   ...
# 125  0NbDnRbBxUaT27CTgmraSG  spotify:track:0NbDnRbBxUaT27CTgmraSG
# 126  5qNh5WtzMbfpSj2jLlBkoD  spotify:track:5qNh5WtzMbfpSj2jLlBkoD
# 127  1HimGOB6BjOaCQYMIF1xtU  spotify:track:1HimGOB6BjOaCQYMIF1xtU
# 128  5Tl8bvgo5shLODXiT9ckva  spotify:track:5Tl8bvgo5shLODXiT9ckva
# 129  2KoHxhRyWxJzA0VafWd5Nk  spotify:track:2KoHxhRyWxJzA0VafWd5Nk
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1is8gU4RVcN4...
# 1    https://api.spotify.com/v1/tracks/7eQHxigpuDJj...
# 2    https://api.spotify.com/v1/tracks/0lx2cLdOt3pi...
# 3    https://api.spotify.com/v1/tracks/0gplL1WMoJ6i...
# 4    https://api.spotify.com/v1/tracks/312zSwwbPU7C...
# ..                                                 ...
# 125  https://api.spotify.com/v1/tracks/0NbDnRbBxUaT...
# 126  https://api.spotify.com/v1/tracks/5qNh5WtzMbfp...
# 127  https://api.spotify.com/v1/tracks/1HimGOB6BjOa...
# 128  https://api.spotify.com/v1/tracks/5Tl8bvgo5shL...
# 129  https://api.spotify.com/v1/tracks/2KoHxhRyWxJz...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1is8...       204094
# 1    https://api.spotify.com/v1/audio-analysis/7eQH...       191250
# 2    https://api.spotify.com/v1/audio-analysis/0lx2...       214707
# 3    https://api.spotify.com/v1/audio-analysis/0gpl...       224695
# 4    https://api.spotify.com/v1/audio-analysis/312z...       204989
# ..                                                 ...          ...
# 125  https://api.spotify.com/v1/audio-analysis/0NbD...       186733
# 126  https://api.spotify.com/v1/audio-analysis/5qNh...       245897
# 127  https://api.spotify.com/v1/audio-analysis/1Him...       184665
# 128  https://api.spotify.com/v1/audio-analysis/5Tl8...       200220
# 129  https://api.spotify.com/v1/audio-analysis/2KoH...       179917
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 125               4
# 126               4
# 127               4
# 128               4
# 129               4
#
# [130 rows x 18 columns]

# %% [markdown]
# # Apply clustering

# %% [markdown]
# ## With scaled data

# %%
# fast lock to our data
plt.scatter(data.iloc[:,0],data.iloc[:,1], data.iloc[:,2],data.iloc[:,3])

# %%
# get the main columns for  clustering
data_selected = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','tempo']]
data_selected
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.422   0.340    -6.577       0.0351        0.8770
# 1           0.700   0.613    -4.041       0.0408        0.3850
# 2           0.392   0.574    -9.195       0.1700        0.8330
# 3           0.604   0.366    -7.519       0.0282        0.5780
# 4           0.562   0.379    -7.625       0.2310        0.5260
# ..            ...     ...       ...          ...           ...
# 125         0.775   0.410    -7.481       0.0464        0.7240
# 126         0.634   0.285   -14.007       0.0807        0.9370
# 127         0.614   0.647    -4.681       0.0524        0.0687
# 128         0.517   0.435    -7.532       0.0278        0.4000
# 129         0.691   0.474    -8.742       0.0583        0.5690
#
#      instrumentalness  liveness  valence    tempo
# 0            0.000018    0.1490    0.223   77.213
# 1            0.000000    0.0887    0.420   88.084
# 2            0.001790    0.1450    0.529   81.112
# 3            0.000000    0.1330    0.130  141.981
# 4            0.000000    0.1510    0.258  171.848
# ..                ...       ...      ...      ...
# 125          0.000026    0.1140    0.298  117.165
# 126          0.000359    0.2320    0.203  129.650
# 127          0.000000    0.1040    0.368  163.862
# 128          0.000000    0.1230    0.335   97.931
# 129          0.000626    0.0990    0.381  143.783
#
# [130 rows x 9 columns]

# %%
# Scale data
data_scaled = fn.st_scaler (data_selected)
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.316265 -0.724237  0.642356    -0.473417      1.277695
# 1        0.915278  1.226520  1.679920    -0.387975     -0.387818
# 2       -1.557079  0.947840 -0.428757     1.548728      1.128747
# 3        0.144674 -0.538451  0.256952    -0.576848      0.265524
# 4       -0.192466 -0.445557  0.213584     2.463115      0.089494
# ..            ...       ...       ...          ...           ...
# 125      1.517314 -0.224043  0.272499    -0.304031      0.759761
# 126      0.385488 -1.117247 -2.397510     0.210125      1.480807
# 127      0.224945  1.469471  1.418074    -0.214091     -1.458554
# 128     -0.553687 -0.045402  0.251633    -0.582844     -0.337040
# 129      0.843034  0.233277 -0.243419    -0.125650      0.235057
#
#      instrumentalness  liveness   valence     tempo
# 0           -0.133846  0.099734 -0.631966 -1.272414
# 1           -0.136286 -0.627059  0.547063 -0.911494
# 2            0.110435  0.051522  1.199419 -1.142966
# 3           -0.136286 -0.093114 -1.188563  0.877905
# 4           -0.136286  0.123839 -0.422494  1.869499
# ..                ...       ...       ...       ...
# 125         -0.132674 -0.322120 -0.183097  0.054005
# 126         -0.086804  1.100129 -0.751664  0.468512
# 127         -0.136286 -0.442649  0.235847  1.604362
# 128         -0.136286 -0.213643  0.038345 -0.584570
# 129         -0.050002 -0.502914  0.313651  0.937732
#
# [130 rows x 9 columns]

# %%
# visualise data to check the shape has not changed through scaling 
data_selected.hist(bins=15,figsize=(15,15));

# %%
data_scaled.hist(bins=15,figsize=(15,15));

# %%
# Use methos KMeans in scaled dataframe - use consistent random state
model = KMeans(n_clusters=10,random_state=5)
cluster_scaled = model.fit(data_scaled)

# %%
# Show the coordinates of each cluster
cluster_scaled.cluster_centers_
# Out:
# array([[-5.35625936e-01,  4.29335489e-01,  3.02442521e-01,
#         -3.44784833e-01, -1.04488339e+00, -1.60318225e-02,
#         -3.78316667e-01, -7.65616386e-01, -2.00014465e-01],
#        [ 2.28798011e-01, -4.11830072e-01,  2.25121298e-01,
#         -3.52658307e-01,  7.98352511e-01, -1.32599480e-01,
#         -3.76984816e-01, -3.49908590e-01,  2.56085274e-01],
#        [ 1.76782184e-01, -1.23872224e+00, -2.42867225e+00,
#          3.16303437e-01,  1.27825960e+00, -1.24532760e-01,
#         -1.38111378e-01, -1.63845523e-01,  2.92267664e-01],
#        [ 3.45351993e-01, -9.67188344e-01, -1.46795728e+00,
#         -3.63990713e-01,  1.30139173e+00,  1.05595162e+01,
#         -2.01590258e-01, -8.23483045e-01, -1.27968524e+00],
#        [ 1.15892561e+00,  3.23590286e-02,  3.09393288e-01,
#         -2.92127103e-01, -4.76340748e-01, -1.31745224e-01,
#         -2.23001973e-01,  1.00543696e+00, -4.13603700e-01],
#        [ 8.38967792e-02,  8.42398967e-02,  1.87808271e-01,
#         -4.17066687e-02, -4.46081354e-02, -9.58996012e-02,
#          2.56628408e+00, -1.36029912e-01,  4.89608089e-01],
#        [ 1.05173976e+00,  6.44150955e-01, -5.08231054e-01,
#          3.95836297e+00, -7.44109269e-01, -1.36052226e-01,
#         -4.67960498e-01,  6.72297155e-01, -7.81323296e-01],
#        [ 5.01881101e-01,  1.54330925e+00,  9.48047550e-01,
#         -8.13467734e-02, -1.03834621e+00,  8.52588673e-02,
#         -3.21517131e-01,  5.57037642e-01,  6.06510545e-02],
#        [-1.42014525e+00, -6.12849221e-01, -5.46467039e-01,
#         -1.49831728e-03,  7.62150892e-01, -1.19560669e-01,
#         -2.58664531e-01, -5.22089703e-01, -1.21757131e+00],
#        [-7.10885023e-01, -8.20107484e-01, -6.71509640e-01,
#          3.33791718e-01,  4.35065214e-01, -1.34706636e-01,
#         -2.97712551e-01,  3.14648533e-01,  1.60276792e+00]])

# %%
# Show the cluster of each row
cluster_scaled.labels_
# Out:
# array([8, 7, 8, 1, 9, 8, 7, 8, 1, 1, 5, 4, 4, 8, 0, 8, 0, 9, 8, 4, 5, 4,
#        1, 4, 5, 9, 9, 9, 1, 7, 0, 5, 4, 9, 7, 4, 1, 1, 5, 8, 6, 8, 8, 1,
#        1, 7, 7, 1, 1, 8, 5, 7, 4, 5, 2, 8, 7, 6, 8, 1, 4, 6, 5, 9, 0, 2,
#        4, 7, 0, 9, 4, 1, 2, 4, 7, 1, 7, 0, 5, 0, 4, 4, 0, 3, 4, 2, 5, 0,
#        0, 1, 9, 4, 5, 1, 9, 7, 9, 5, 0, 0, 1, 7, 1, 7, 1, 1, 5, 0, 7, 1,
#        8, 1, 5, 1, 0, 8, 0, 7, 6, 7, 4, 9, 2, 8, 8, 1, 2, 7, 0, 1])

# %%
#add cluster back into scaled data
data_scaled['cluster_no'] = cluster_scaled.labels_
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.316265 -0.724237  0.642356    -0.473417      1.277695
# 1        0.915278  1.226520  1.679920    -0.387975     -0.387818
# 2       -1.557079  0.947840 -0.428757     1.548728      1.128747
# 3        0.144674 -0.538451  0.256952    -0.576848      0.265524
# 4       -0.192466 -0.445557  0.213584     2.463115      0.089494
# ..            ...       ...       ...          ...           ...
# 125      1.517314 -0.224043  0.272499    -0.304031      0.759761
# 126      0.385488 -1.117247 -2.397510     0.210125      1.480807
# 127      0.224945  1.469471  1.418074    -0.214091     -1.458554
# 128     -0.553687 -0.045402  0.251633    -0.582844     -0.337040
# 129      0.843034  0.233277 -0.243419    -0.125650      0.235057
#
#      instrumentalness  liveness   valence     tempo  cluster_no
# 0           -0.133846  0.099734 -0.631966 -1.272414           8
# 1           -0.136286 -0.627059  0.547063 -0.911494           7
# 2            0.110435  0.051522  1.199419 -1.142966           8
# 3           -0.136286 -0.093114 -1.188563  0.877905           1
# 4           -0.136286  0.123839 -0.422494  1.869499           9
# ..                ...       ...       ...       ...         ...
# 125         -0.132674 -0.322120 -0.183097  0.054005           1
# 126         -0.086804  1.100129 -0.751664  0.468512           2
# 127         -0.136286 -0.442649  0.235847  1.604362           7
# 128         -0.136286 -0.213643  0.038345 -0.584570           0
# 129         -0.050002 -0.502914  0.313651  0.937732           1
#
# [130 rows x 10 columns]

# %%
data_scaled['cluster_no'].value_counts()
# Out:
# 1    25
# 7    18
# 8    17
# 4    17
# 0    16
# 5    14
# 9    12
# 2     6
# 6     4
# 3     1
# Name: cluster_no, dtype: int64

# %% [markdown]
# ## With normal data

# %%
# New Dataframe to keep the original
data_normal = data_selected

# %%
# Use methos KMeans in normal dataframe - use consistent random state
cluster_normal = model.fit(data_normal)

# %%
# Show the coordinates of each cluster
cluster_normal.cluster_centers_
# Out:
# array([[ 4.84900000e-01,  3.54800000e-01, -9.15600000e+00,
#          9.79000000e-02,  5.59400000e-01,  4.10466000e-04,
#          1.86900000e-01,  3.36120000e-01,  1.73994300e+02],
#        [ 6.61642857e-01,  3.76071429e-01, -8.45378571e+00,
#          6.58714286e-02,  5.77457143e-01,  2.90650000e-05,
#          1.59342857e-01,  3.32514286e-01,  1.07529429e+02],
#        [ 6.24461538e-01,  5.45384615e-01, -6.99007692e+00,
#          1.21046154e-01,  2.79615385e-01,  7.81015385e-05,
#          1.66453846e-01,  3.90207692e-01,  8.92913077e+01],
#        [ 6.29533333e-01,  4.40733333e-01, -7.59180000e+00,
#          4.50533333e-02,  4.61200000e-01,  1.94154000e-04,
#          1.37533333e-01,  2.89133333e-01,  1.31204200e+02],
#        [ 2.86000000e-01,  4.45000000e-01, -8.08700000e+00,
#          3.47000000e-02,  3.55000000e-01,  0.00000000e+00,
#          1.14000000e-01,  2.78000000e-01,  5.08270000e+01],
#        [ 5.68866667e-01,  5.13266667e-01, -7.27060000e+00,
#          5.07600000e-02,  4.25904000e-01,  1.90000000e-03,
#          1.12113333e-01,  3.12166667e-01,  9.74120000e+01],
#        [ 6.10368421e-01,  4.61578947e-01, -7.78068421e+00,
#          5.65000000e-02,  4.72489474e-01,  6.41631579e-05,
#          1.46684211e-01,  3.01852632e-01,  1.43643737e+02],
#        [ 5.05666667e-01,  3.78083333e-01, -9.20383333e+00,
#          7.37333333e-02,  6.37895833e-01,  3.31998792e-03,
#          1.16362500e-01,  3.03304167e-01,  7.81920000e+01],
#        [ 6.59538462e-01,  4.71153846e-01, -7.98823077e+00,
#          4.08153846e-02,  5.36903846e-01,  8.13015385e-04,
#          1.34169231e-01,  3.92307692e-01,  1.21437462e+02],
#        [ 5.63000000e-01,  4.58166667e-01, -9.12266667e+00,
#          5.80500000e-02,  4.50283333e-01,  2.22850000e-05,
#          1.41333333e-01,  3.69333333e-01,  1.58207833e+02]])

# %%
# Show the cluster of each row
cluster_normal.labels_
# Out:
# array([7, 2, 7, 6, 0, 7, 5, 7, 3, 6, 8, 5, 8, 7, 3, 7, 3, 0, 4, 6, 3, 2,
#        1, 1, 6, 9, 0, 6, 6, 6, 7, 1, 7, 0, 3, 2, 1, 6, 2, 7, 2, 7, 7, 8,
#        5, 5, 6, 8, 7, 7, 1, 5, 7, 6, 9, 7, 7, 1, 5, 6, 7, 2, 0, 9, 6, 7,
#        1, 8, 2, 8, 1, 2, 8, 3, 9, 6, 6, 1, 0, 5, 8, 7, 3, 7, 1, 1, 6, 3,
#        7, 3, 0, 8, 1, 3, 9, 5, 0, 0, 3, 5, 5, 3, 8, 2, 1, 6, 3, 1, 5, 8,
#        7, 3, 2, 5, 8, 5, 2, 2, 2, 6, 5, 0, 6, 7, 7, 8, 3, 9, 5, 6])

# %%
#add cluster back into normal data
data_normal['cluster_no'] = cluster_normal.labels_
data_normal
# Out:
# C:\Users\Agus\AppData\Local\Temp/ipykernel_9400/263779458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_normal['cluster_no'] = cluster_normal.labels_
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.422   0.340    -6.577       0.0351        0.8770
# 1           0.700   0.613    -4.041       0.0408        0.3850
# 2           0.392   0.574    -9.195       0.1700        0.8330
# 3           0.604   0.366    -7.519       0.0282        0.5780
# 4           0.562   0.379    -7.625       0.2310        0.5260
# ..            ...     ...       ...          ...           ...
# 125         0.775   0.410    -7.481       0.0464        0.7240
# 126         0.634   0.285   -14.007       0.0807        0.9370
# 127         0.614   0.647    -4.681       0.0524        0.0687
# 128         0.517   0.435    -7.532       0.0278        0.4000
# 129         0.691   0.474    -8.742       0.0583        0.5690
#
#      instrumentalness  liveness  valence    tempo  cluster_no
# 0            0.000018    0.1490    0.223   77.213           7
# 1            0.000000    0.0887    0.420   88.084           2
# 2            0.001790    0.1450    0.529   81.112           7
# 3            0.000000    0.1330    0.130  141.981           6
# 4            0.000000    0.1510    0.258  171.848           0
# ..                ...       ...      ...      ...         ...
# 125          0.000026    0.1140    0.298  117.165           8
# 126          0.000359    0.2320    0.203  129.650           3
# 127          0.000000    0.1040    0.368  163.862           9
# 128          0.000000    0.1230    0.335   97.931           5
# 129          0.000626    0.0990    0.381  143.783           6
#
# [130 rows x 10 columns]

# %%
data_normal['cluster_no'].value_counts()
# Out:
# 7    24
# 6    19
# 5    15
# 3    15
# 1    14
# 2    13
# 8    13
# 0    10
# 9     6
# 4     1
# Name: cluster_no, dtype: int64

# %% [markdown]
# # Getting the best K

# %%
###  3 metrics : inertia, distortion, silouhette score

# %%
# lets remove the cluster from my df to make the model again
data_scaled = data_scaled.drop('cluster_no',axis=1)
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.316265 -0.724237  0.642356    -0.473417      1.277695
# 1        0.915278  1.226520  1.679920    -0.387975     -0.387818
# 2       -1.557079  0.947840 -0.428757     1.548728      1.128747
# 3        0.144674 -0.538451  0.256952    -0.576848      0.265524
# 4       -0.192466 -0.445557  0.213584     2.463115      0.089494
# ..            ...       ...       ...          ...           ...
# 125      1.517314 -0.224043  0.272499    -0.304031      0.759761
# 126      0.385488 -1.117247 -2.397510     0.210125      1.480807
# 127      0.224945  1.469471  1.418074    -0.214091     -1.458554
# 128     -0.553687 -0.045402  0.251633    -0.582844     -0.337040
# 129      0.843034  0.233277 -0.243419    -0.125650      0.235057
#
#      instrumentalness  liveness   valence     tempo
# 0           -0.133846  0.099734 -0.631966 -1.272414
# 1           -0.136286 -0.627059  0.547063 -0.911494
# 2            0.110435  0.051522  1.199419 -1.142966
# 3           -0.136286 -0.093114 -1.188563  0.877905
# 4           -0.136286  0.123839 -0.422494  1.869499
# ..                ...       ...       ...       ...
# 125         -0.132674 -0.322120 -0.183097  0.054005
# 126         -0.086804  1.100129 -0.751664  0.468512
# 127         -0.136286 -0.442649  0.235847  1.604362
# 128         -0.136286 -0.213643  0.038345 -0.584570
# 129         -0.050002 -0.502914  0.313651  0.937732
#
# [130 rows x 9 columns]

# %%
K = range(8,18)
inertia = []
for k in K:
    best_model = KMeans(n_clusters=k,random_state=5)
    best_model.fit(data_scaled)
    inertia.append(best_model.inertia_)

# %%
#plot the resulting inertia - elbow 
plt.figure(figsize=(16,8))
plt.plot(K,inertia,'bx-')
plt.xlabel('k=noofclusters')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('elbow method inertia to find optimal K');

# %%
K = range(5,18)
sil = []
for k in K:
    best_model = KMeans(n_clusters=k,random_state=5)
    best_model.fit(data_scaled)
    sil.append(silhouette_score(data_scaled,best_model.predict(data_scaled)))

# %%
#plot the resulting silhouette 
plt.figure(figsize=(16,8))
plt.plot(K,sil,'bo-')
plt.xlabel('k=noofclusters')
plt.ylabel('silhouette')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('silhouette score');

# %%
# watching the plot, 11 seems the best k
# Try again with scaled data and best k
model=KMeans(n_clusters=11, random_state=5)
cluster_best=model.fit(data_scaled)
data_scaled['cluster_final'] = cluster_best.labels_

# %%
data_scaled['cluster_final'].value_counts()
# Out:
# 10    19
# 6     18
# 8     17
# 2     16
# 4     15
# 9     13
# 1     12
# 0     12
# 7      5
# 5      2
# 3      1
# Name: cluster_final, dtype: int64

# %%
data_scaled.head(1)
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -1.316265 -0.724237  0.642356    -0.473417      1.277695
#
#    instrumentalness  liveness   valence     tempo  cluster_final
# 0         -0.133846  0.099734 -0.631966 -1.272414             10

# %%
def spotify_display(song_name_id):
        display(IFrame(src=f"https://open.spotify.com/embed/track/{song_name_id}",
                        width="320",
                        height="80",
                        frameborder="0",
                        allowtransparency="true",
                        allow="encrypted-media",))

# %% [markdown]
# # Show results with GUI (Tkinter)

# %%
# Create a new window
def try_again(window):
    window.destroy()
    create()

# Close window
def close(window):
    window.destroy()

# Show the results after compare input and top[song] when the match is positive
# Check has the Dataframe with 1 positive result
def but_yes(window,check):
    # Create a new dataframe without result to avoid repeat
    result = top.drop(labels=check.index, axis=0)

    # Create a new dataframe with a random sample to share
    result = result.sample()
    song_res = result['Song'].item()
    artist_res = result['Artist'].item()

    # Change size os window
    window.geometry("")
    # Show the results
    res1 = tk.Label(window, text = 'Nice choice, your song is in the top 100, maybe you like this one too')
    res1.pack(fill = tk.X)
    res2 = tk.Label(window, text = f'{song_res} - {artist_res}')
    res2.pack(fill = tk.X)
    space = tk.Label(window, text = "   ")
    space.pack(fill = tk.X)
    
    #  Ask for Try Again
    label_no = tk.Label(window, text = 'Do you want to try again?')
    label_no.pack(fill = tk.X)
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()

#If the match is negative, show the result and ask for Try Again
def but_no(window,best):
    track = 'abcdefu'
    artist = 'gayle'
    # track_id is a request wit artist & song
    track_id = sp.search(q='track:' + best, type='track', limit=1)
    track_id
    
    # x is the id that we are looking for
    x = track_id["tracks"]['items'][0]['id']
    x
    
    ###############################################spotify_display(x)
    
    # audio_feature is a dataframe with the results 
    audio_feat=pd.DataFrame(sp.audio_features(tracks=x))
    audio_feat
    
    # get the main columns for  clustering
    audio_feat = audio_feat[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','tempo']]
    audio_feat
    
    # fit without column cluster
    scaler=StandardScaler()
    model = scaler.fit(data_scaled.drop('cluster_final',axis=1)).transform(audio_feat)
    model
    
    # dataframe with audio feature scaled
    audio_scaled = pd.DataFrame(model, index=audio_feat.index, columns=audio_feat.columns)
    audio_scaled
    
    # predict the cluster and get the number
    model=KMeans(n_clusters=11, random_state=5)
    cluster_best=model.fit(data_scaled.drop('cluster_final',axis=1))
    pred = cluster_best.predict(audio_scaled)
    pred[0]
    
    # use new cluster to get a index of random song with the same cluster
    samp = data_scaled[data_scaled.cluster_final==pred[0]].sample(1).index.item()
    samp
    
    # use that index to get the id of new song
    data_samp = data[samp:samp+1]
    data_samp
    
    #use id to get the song and the artist name
    for key, value in list_info.items():
        if key == data_samp['id'].item():
            song_artist = value
    
    #Buttons
    label_no = tk.Label(window, text = f'Sorry, I dont know what song you mean.\n But according to your song you may like this one. \n {song_artist[0]} - {song_artist[1]} \n Do you want to try again?')
    label_no.pack(fill = tk.X)
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()

# Get data from inputs
def get_data(input_song,window):
    # Transform to string
    songs = input_song.get()
    if len(songs) == 0:
        messagebox.showwarning('Error','You need to enter at least one song.')
    else:        
        # fuzz token compare the input with the songs of the dataframe
        # we save in -best- the best result
        res = 0
        for x in top['Song']:
            if fuzz.token_set_ratio(x,songs) > res:
                res = fuzz.token_set_ratio(x,songs)
                best = x

        # get data from best result
        check = top[(top['Song']==best)]
        artist = check['Artist'].item()

        # Show the results
        window.geometry("")
        ask = tk.Label(window, text = f'Did you mean this song? ->  {best} - {artist}')
        ask.pack(fill = tk.X)
    
        button_yes = tk.Button(window, text = 'Yes', command = lambda: but_yes(window,check))
        button_yes.pack()
        button_no = tk.Button(window, text = 'No', command = lambda: but_no(window,best))
        button_no.pack()
        space = tk.Label(window, text = "   ")
        space.pack(fill = tk.X)

# Create the main window
def create():
    
    # Create a window
    window = tk.Tk()

    #Change size os window
    window.geometry("")

    # Title
    title = tk.Label(window, text = 'Enter a song and/or an artist to see if its in the top 100', bg = 'gray51')
    title.pack(fill = tk.X)

    #Take song
    title_song = tk.Label(window, text = 'Enter a song')
    title_song.pack(fill = tk.X)
    input_song = tk.Entry(window)
    input_song.pack()

    button_search = tk.Button(window, text = 'Search', command = lambda: get_data(input_song,window))
    button_search.pack()
    space = tk.Label(window, text = "   ")
    space.pack(fill = tk.X)
    
    #That comand open the window
    window.mainloop()

# %%
create()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Agus\anaconda3\envs\class\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Agus\AppData\Local\Temp/ipykernel_9400/1887801077.py", line 123, in <lambda>
#     button_no = tk.Button(window, text = 'No', command = lambda: but_no(window,best))
#   File "C:\Users\Agus\AppData\Local\Temp/ipykernel_9400/1887801077.py", line 51, in but_no
#     spotify_display(x)
#   File "C:\Users\Agus\AppData\Local\Temp/ipykernel_9400/2258354827.py", line 2, in spotify_display
#     display(IFrame(src=f"https://open.spotify.com/embed/track/{song_name_id}",
# NameError: name 'IFrame' is not defined
