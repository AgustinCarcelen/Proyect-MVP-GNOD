# %% [markdown]
# # Imports

# %%
#Library to make GUI
from tkinter import messagebox
import tkinter as tk

import requests 
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import getpass

from fuzzywuzzy import fuzz

import matplotlib.pyplot as plt 

import functions as fn

from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score 

from sklearn.preprocessing import StandardScaler 

from IPython.core.display import display
from IPython.display import IFrame

# %% [markdown]
# # Get Data from Billboard to know de 100 hot songs

# %%
# Create URL
url = "https://www.billboard.com/charts/hot-100/"

# Create a request
results=requests.get(url, headers = {"Accept-Language": "en-US"})

# Result in string
#results.text

# We use BeautifulSoup to extract specific results
soup = BeautifulSoup(results.content,'html.parser')

# Show results in html mode
#print(soup.prettify())

# Strip=True => You can tell Beautiful Soup to strip whitespace from the beginning and end of each bit of text
# Try get the first name of song
soup.select('h3.c-title.a-no-trucate')[0].get_text(strip=True)

# Try get the first artist of song
soup.select('span.c-label.a-no-trucate')[0].get_text(strip=True)

# Calculate the len of our select
len_songs = len(soup.select('h3.c-title.a-no-trucate'))

# Create variables to store results
song = []
artist = []

# Create a for to pick the 100 best songs
for x in range(len_songs):
    song.append(soup.select('h3.c-title.a-no-trucate')[x].get_text(strip=True))
    artist.append(soup.select('span.c-label.a-no-trucate')[x].get_text(strip=True))
    
# Import pandas to create a data frame
top = pd.DataFrame({'Song':song, 'Artist':artist})
#top

# Import numpy to add a Rank
top['Rank'] = np.arange(len(top))+1
top
# Out:
#                                Song  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                           abcdefu
# 3                        Easy On Me
# 4                     Super Gremlin
# ..                              ...
# 95                           Closer
# 96                    Cold December
# 97                Get Into It (Yuh)
# 98  All Too Well (Taylor's Version)
# 99            Give Heaven Some Hell
#
#                                                Artist  Rank
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...     1
# 1                                       Glass Animals     2
# 2                                               GAYLE     3
# 3                                               Adele     4
# 4                                         Kodak Black     5
# ..                                                ...   ...
# 95                          Saweetie Featuring H.E.R.    96
# 96                                           Rod Wave    97
# 97                                           Doja Cat    98
# 98                                       Taylor Swift    99
# 99                                              HARDY   100
#
# [100 rows x 3 columns]

# %% [markdown]
# # Get playlist from Spotify to analice audio features

# %%
# Get usser and pass
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))

# Create a conexion
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Get random playlist
playlist = sp.user_playlist_tracks("Spotify","37i9dQZF1DX4WYpdgoIcn6")
playlist
# Out:
# client_id?········
# client_secret?········
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7okSU80WTrn4LXlyXYbX3P'},
#        'href': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P',
#        'id': '7okSU80WTrn4LXlyXYbX3P',
#        'name': 'Clinton Kane',
#        'type': 'artist',
#        'uri': 'spotify:artist:7okSU80WTrn4LXlyXYbX3P'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56meo2KJ9tRlaGUHSGfTpP'},
#      'href': 'https://api.spotify.com/v1/albums/56meo2KJ9tRlaGUHSGfTpP',
#      'id': '56meo2KJ9tRlaGUHSGfTpP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ff62d5125efd086e3c23dfb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ff62d5125efd086e3c23dfb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ff62d5125efd086e3c23dfb',
#        'width': 64}],
#      'name': "I GUESS I'M IN LOVE",
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:56meo2KJ9tRlaGUHSGfTpP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7okSU80WTrn4LXlyXYbX3P'},
#       'href': 'https://api.spotify.com/v1/artists/7okSU80WTrn4LXlyXYbX3P',
#       'id': '7okSU80WTrn4LXlyXYbX3P',
#       'name': 'Clinton Kane',
#       'type': 'artist',
#       'uri': 'spotify:artist:7okSU80WTrn4LXlyXYbX3P'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12104467'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1is8gU4RVcN4J8xItxWoOY'},
#     'href': 'https://api.spotify.com/v1/tracks/1is8gU4RVcN4J8xItxWoOY',
#     'id': '1is8gU4RVcN4J8xItxWoOY',
#     'is_local': False,
#     'name': "I GUESS I'M IN LOVE",
#     'popularity': 87,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cf41c8b3268141df27b6a252f0b4ea72f6453901?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1is8gU4RVcN4J8xItxWoOY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bqxdqvUtPWZri43cKHac8'},
#        'href': 'https://api.spotify.com/v1/artists/1bqxdqvUtPWZri43cKHac8',
#        'id': '1bqxdqvUtPWZri43cKHac8',
#        'name': 'MAX',
#        'type': 'artist',
#        'uri': 'spotify:artist:1bqxdqvUtPWZri43cKHac8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#        'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#        'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#        'name': 'Ali Gatie',
#        'type': 'artist',
#        'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4TENiEyNNnHbRixbSa0XKg'},
#      'href': 'https://api.spotify.com/v1/albums/4TENiEyNNnHbRixbSa0XKg',
#      'id': '4TENiEyNNnHbRixbSa0XKg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b7c878bdc17d023295df222',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b7c878bdc17d023295df222',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b7c878bdc17d023295df222',
#        'width': 64}],
#      'name': 'Butterflies',
#      'release_date': '2021-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4TENiEyNNnHbRixbSa0XKg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bqxdqvUtPWZri43cKHac8'},
#       'href': 'https://api.spotify.com/v1/artists/1bqxdqvUtPWZri43cKHac8',
#       'id': '1bqxdqvUtPWZri43cKHac8',
#       'name': 'MAX',
#       'type': 'artist',
#       'uri': 'spotify:artist:1bqxdqvUtPWZri43cKHac8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#       'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#       'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#       'name': 'Ali Gatie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 191250,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12101365'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7eQHxigpuDJjCG50JyzU8v'},
#     'href': 'https://api.spotify.com/v1/tracks/7eQHxigpuDJjCG50JyzU8v',
#     'id': '7eQHxigpuDJjCG50JyzU8v',
#     'is_local': False,
#     'name': 'Butterflies',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f22a6a785f71592ee7e099c4c0596bc4a115e735?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7eQHxigpuDJjCG50JyzU8v'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Xoteh7uEpea4TohMxjtaq'},
#      'href': 'https://api.spotify.com/v1/albums/2Xoteh7uEpea4TohMxjtaq',
#      'id': '2Xoteh7uEpea4TohMxjtaq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27333b8541201f1ef38941024be',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0233b8541201f1ef38941024be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485133b8541201f1ef38941024be',
#        'width': 64}],
#      'name': 'evermore',
#      'release_date': '2020-12-11',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2Xoteh7uEpea4TohMxjtaq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 214706,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12004699'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0lx2cLdOt3piJbcaXIV74f'},
#     'href': 'https://api.spotify.com/v1/tracks/0lx2cLdOt3piJbcaXIV74f',
#     'id': '0lx2cLdOt3piJbcaXIV74f',
#     'is_local': False,
#     'name': 'willow',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0lx2cLdOt3piJbcaXIV74f'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AVfmawzu83sp94QW7CEGm'},
#        'href': 'https://api.spotify.com/v1/artists/3AVfmawzu83sp94QW7CEGm',
#        'id': '3AVfmawzu83sp94QW7CEGm',
#        'name': 'Astrid S',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AVfmawzu83sp94QW7CEGm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2C91kmyDRWZdm0wR8dK1Wn'},
#      'href': 'https://api.spotify.com/v1/albums/2C91kmyDRWZdm0wR8dK1Wn',
#      'id': '2C91kmyDRWZdm0wR8dK1Wn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d7ef0f772d6506524ade7fd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d7ef0f772d6506524ade7fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d7ef0f772d6506524ade7fd',
#        'width': 64}],
#      'name': "It's Ok If You Forget Me",
#      'release_date': '2020-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2C91kmyDRWZdm0wR8dK1Wn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AVfmawzu83sp94QW7CEGm'},
#       'href': 'https://api.spotify.com/v1/artists/3AVfmawzu83sp94QW7CEGm',
#       'id': '3AVfmawzu83sp94QW7CEGm',
#       'name': 'Astrid S',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AVfmawzu83sp94QW7CEGm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204989,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NOUM72000369'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/312zSwwbPU7C3sTmro4Wx9'},
#     'href': 'https://api.spotify.com/v1/tracks/312zSwwbPU7C3sTmro4Wx9',
#     'id': '312zSwwbPU7C3sTmro4Wx9',
#     'is_local': False,
#     'name': "It's Ok If You Forget Me",
#     'popularity': 72,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:312zSwwbPU7C3sTmro4Wx9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#        'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#        'id': '4dpARuHxo51G3z768sgnrY',
#        'name': 'Adele',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/224jZ4sUX7OhAuMwaxp86S'},
#      'href': 'https://api.spotify.com/v1/albums/224jZ4sUX7OhAuMwaxp86S',
#      'id': '224jZ4sUX7OhAuMwaxp86S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350dba34377a595e35f81b0e4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250dba34377a595e35f81b0e4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150dba34377a595e35f81b0e4',
#        'width': 64}],
#      'name': 'Easy On Me',
#      'release_date': '2021-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:224jZ4sUX7OhAuMwaxp86S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 224694,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12105970'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0gplL1WMoJ6iYaPgMCL0gX'},
#     'href': 'https://api.spotify.com/v1/tracks/0gplL1WMoJ6iYaPgMCL0gX',
#     'id': '0gplL1WMoJ6iYaPgMCL0gX',
#     'is_local': False,
#     'name': 'Easy On Me',
#     'popularity': 95,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c5014be1aeb2ab5f129e2789eff3ea87ecd5027f?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0gplL1WMoJ6iYaPgMCL0gX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#        'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#        'id': '3gIRvgZssIb9aiirIg0nI3',
#        'name': 'Jeremy Zucker',
#        'type': 'artist',
#        'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#        'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#        'id': '5JMLG56F1X5mFmWNmS0iAp',
#        'name': 'Chelsea Cutler',
#        'type': 'artist',
#        'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nAv0lNEyaR9IC0RR2UQiW'},
#      'href': 'https://api.spotify.com/v1/albums/5nAv0lNEyaR9IC0RR2UQiW',
#      'id': '5nAv0lNEyaR9IC0RR2UQiW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dccb079c492cf99e02e3255b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dccb079c492cf99e02e3255b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dccb079c492cf99e02e3255b',
#        'width': 64}],
#      'name': 'this is how you fall in love',
#      'release_date': '2021-01-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5nAv0lNEyaR9IC0RR2UQiW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#       'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#       'id': '3gIRvgZssIb9aiirIg0nI3',
#       'name': 'Jeremy Zucker',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#       'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#       'id': '5JMLG56F1X5mFmWNmS0iAp',
#       'name': 'Chelsea Cutler',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 174586,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72024519'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0742PcMPo2Akmo4vHC29VZ'},
#     'href': 'https://api.spotify.com/v1/tracks/0742PcMPo2Akmo4vHC29VZ',
#     'id': '0742PcMPo2Akmo4vHC29VZ',
#     'is_local': False,
#     'name': 'this is how you fall in love',
#     'popularity': 4,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0742PcMPo2Akmo4vHC29VZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3RqBeV12Tt7A8xH3zBDDUF'},
#        'href': 'https://api.spotify.com/v1/artists/3RqBeV12Tt7A8xH3zBDDUF',
#        'id': '3RqBeV12Tt7A8xH3zBDDUF',
#        'name': 'Kelsea Ballerini',
#        'type': 'artist',
#        'uri': 'spotify:artist:3RqBeV12Tt7A8xH3zBDDUF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#        'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#        'id': '49tQo2QULno7gxHutgccqF',
#        'name': 'LANY',
#        'type': 'artist',
#        'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5c5S9cyjHKBQRm1DGU1E8J'},
#      'href': 'https://api.spotify.com/v1/albums/5c5S9cyjHKBQRm1DGU1E8J',
#      'id': '5c5S9cyjHKBQRm1DGU1E8J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b0be5e7275db8b7baa1ef779',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b0be5e7275db8b7baa1ef779',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b0be5e7275db8b7baa1ef779',
#        'width': 64}],
#      'name': 'I Quit Drinking',
#      'release_date': '2021-06-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5c5S9cyjHKBQRm1DGU1E8J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3RqBeV12Tt7A8xH3zBDDUF'},
#       'href': 'https://api.spotify.com/v1/artists/3RqBeV12Tt7A8xH3zBDDUF',
#       'id': '3RqBeV12Tt7A8xH3zBDDUF',
#       'name': 'Kelsea Ballerini',
#       'type': 'artist',
#       'uri': 'spotify:artist:3RqBeV12Tt7A8xH3zBDDUF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#       'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#       'id': '49tQo2QULno7gxHutgccqF',
#       'name': 'LANY',
#       'type': 'artist',
#       'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 171200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6P42178163'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6OcCk1dbAb7XNHsC098oEM'},
#     'href': 'https://api.spotify.com/v1/tracks/6OcCk1dbAb7XNHsC098oEM',
#     'id': '6OcCk1dbAb7XNHsC098oEM',
#     'is_local': False,
#     'name': 'I Quit Drinking',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c8e0d30e0ec595d89783ffbde402ae4b975a75c4?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6OcCk1dbAb7XNHsC098oEM'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#        'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#        'id': '7n2wHs1TKAczGzO7Dd2rGr',
#        'name': 'Shawn Mendes',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3sDud6BapENewYxlL8VH8r'},
#      'href': 'https://api.spotify.com/v1/albums/3sDud6BapENewYxlL8VH8r',
#      'id': '3sDud6BapENewYxlL8VH8r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27372355b30dde4b6ded10ef48c',
#        'width': 640},
#       {'height': 300,
# ...
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2cUg7ckSqDt8gXp9tmfdZ5'},
#      'href': 'https://api.spotify.com/v1/albums/2cUg7ckSqDt8gXp9tmfdZ5',
#      'id': '2cUg7ckSqDt8gXp9tmfdZ5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c6d74e14e3f5006b8489526',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c6d74e14e3f5006b8489526',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c6d74e14e3f5006b8489526',
#        'width': 64}],
#      'name': 'cowboy in LA',
#      'release_date': '2020-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:2cUg7ckSqDt8gXp9tmfdZ5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#       'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#       'id': '49tQo2QULno7gxHutgccqF',
#       'name': 'LANY',
#       'type': 'artist',
#       'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 213800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72003712'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0E6uWutxRjIDhleURR92do'},
#     'href': 'https://api.spotify.com/v1/tracks/0E6uWutxRjIDhleURR92do',
#     'id': '0E6uWutxRjIDhleURR92do',
#     'is_local': False,
#     'name': 'cowboy in LA',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0E6uWutxRjIDhleURR92do'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#        'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#        'id': '64KEffDW9EtZ1y2vBYgq8T',
#        'name': 'Marshmello',
#        'type': 'artist',
#        'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#        'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#        'id': '26VFTg2z8YR0cCuwLzESi2',
#        'name': 'Halsey',
#        'type': 'artist',
#        'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1eleCBhP2R8TXEDquvybwC'},
#      'href': 'https://api.spotify.com/v1/albums/1eleCBhP2R8TXEDquvybwC',
#      'id': '1eleCBhP2R8TXEDquvybwC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fdf2e993e10e67396b3bf759',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fdf2e993e10e67396b3bf759',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fdf2e993e10e67396b3bf759',
#        'width': 64}],
#      'name': 'Be Kind (with Halsey)',
#      'release_date': '2020-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1eleCBhP2R8TXEDquvybwC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#       'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#       'id': '64KEffDW9EtZ1y2vBYgq8T',
#       'name': 'Marshmello',
#       'type': 'artist',
#       'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#       'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#       'id': '26VFTg2z8YR0cCuwLzESi2',
#       'name': 'Halsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 172761,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12001567'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Z8FwOEN59mRMxDCtb8N0A'},
#     'href': 'https://api.spotify.com/v1/tracks/3Z8FwOEN59mRMxDCtb8N0A',
#     'id': '3Z8FwOEN59mRMxDCtb8N0A',
#     'is_local': False,
#     'name': 'Be Kind (with Halsey)',
#     'popularity': 81,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3Z8FwOEN59mRMxDCtb8N0A'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-03-04T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#        'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#        'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#        'name': 'Ali Gatie',
#        'type': 'artist',
#        'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Mxvm1AvvhrohYFo1VlhXZ'},
#      'href': 'https://api.spotify.com/v1/albums/4Mxvm1AvvhrohYFo1VlhXZ',
#      'id': '4Mxvm1AvvhrohYFo1VlhXZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e96cdb45964ae7c03c987246',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e96cdb45964ae7c03c987246',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e96cdb45964ae7c03c987246',
#        'width': 64}],
#      'name': "Can't Let You Go",
#      'release_date': '2021-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4Mxvm1AvvhrohYFo1VlhXZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4rTv3Ejc7hKMtmoBOK1B4T'},
#       'href': 'https://api.spotify.com/v1/artists/4rTv3Ejc7hKMtmoBOK1B4T',
#       'id': '4rTv3Ejc7hKMtmoBOK1B4T',
#       'name': 'Ali Gatie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rTv3Ejc7hKMtmoBOK1B4T'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 204156,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12004285'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RfrZ5Lgr3fdtgnvhh3va8'},
#     'href': 'https://api.spotify.com/v1/tracks/5RfrZ5Lgr3fdtgnvhh3va8',
#     'id': '5RfrZ5Lgr3fdtgnvhh3va8',
#     'is_local': False,
#     'name': "Can't Let You Go",
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/32ba0a07bbdd41b488a4f37cb8ce53d8d3c4c68f?cid=d39c4b4a711f4cf591ae66e9f81afe60',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5RfrZ5Lgr3fdtgnvhh3va8'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 130}

# %%
#dictionary comprehension 
list_info = {
  track["track"]["id"]: [track["track"]["name"], 
  track["track"]["artists"][0]["name"]] 
  for track in playlist["items"]
}
list_info
# Out:
# {'1is8gU4RVcN4J8xItxWoOY': ["I GUESS I'M IN LOVE", 'Clinton Kane'],
#  '7eQHxigpuDJjCG50JyzU8v': ['Butterflies', 'MAX'],
#  '0lx2cLdOt3piJbcaXIV74f': ['willow', 'Taylor Swift'],
#  '312zSwwbPU7C3sTmro4Wx9': ["It's Ok If You Forget Me", 'Astrid S'],
#  '0gplL1WMoJ6iYaPgMCL0gX': ['Easy On Me', 'Adele'],
#  '0742PcMPo2Akmo4vHC29VZ': ['this is how you fall in love', 'Jeremy Zucker'],
#  '6OcCk1dbAb7XNHsC098oEM': ['I Quit Drinking', 'Kelsea Ballerini'],
#  '2KnLkZ3z7PO3kgVGHGqDpD': ["It'll Be Okay", 'Shawn Mendes'],
#  '5WtfUKzXircvW8l5aaVZWT': ['What A Time (feat. Niall Horan)',
#   'Julia Michaels'],
#  '7lPN2DXiMsVn7XUKtOW1CS': ['drivers license', 'Olivia Rodrigo'],
#  '1nYzjrdVQ8RpF93M0jPFW7': ['Remember That Night?', 'Sara Kays'],
#  '0ohcCrxZkBfFbkuRPOZQZX': ['dancing in the kitchen', 'LANY'],
#  '4IQkfUsrwXol38VV3U7t7T': ['Run (feat. Ed Sheeran) (Taylor’s Version) (From The Vault)',
#   'Taylor Swift'],
#  '2h9TDNEXRhcDIV3fsoEVq9': ['What Other People Say', 'Sam Fischer'],
#  '4cGqn0E8JCSY9gQllQj4Mf': ['Let Somebody Go', 'Coldplay'],
#  '6GH4tLwGW6HliKbZBdt6hD': ['Unlearn (with Gracie Abrams)', 'benny blanco'],
#  '727Z2S2mtNH46CbP9EWPwY': ['If You Love Her', 'Forest Blakk'],
#  '2URXzpbSUwOjltvpgtzXua': ['You Will Be Found (with Summer Walker) - From The “Dear Evan Hansen” Original Motion Picture Soundtrack',
#   'Sam Smith'],
#  '135Lf4Q0CzlMNfOxbEUsLH': ['GHOST TOWN', 'Benson Boone'],
#  '2Z8yfpFX0ZMavHkcIeHiO1': ['Monster (Shawn Mendes & Justin Bieber)',
#   'Shawn Mendes'],
#  '6N1K5OVVCopBjGViHs2IvP': ['The Joker And The Queen (feat. Taylor Swift)',
#   'Ed Sheeran'],
#  '1ZMiCix7XSAbfAJlEZWMCp': ['Falling', 'Harry Styles'],
#  '1EHUQesfVKwbthtNcpBi9g': ['WITHOUT YOU (with Miley Cyrus)', 'The Kid LAROI'],
#  '6s86N7LVaJZuU4alwKp6XO': ['Are you happy?', 'SHY Martin'],
#  '1bd4heB3yXc5iFTPoOMPuo': ['slower', 'Tate McRae'],
#  '58qX77t2VWMWcycsh9zKLc': ["i don't want to watch the world end with someone else",
#   'Clinton Kane'],
#  '2J4DpqJCIuuM9WjtWHbjvd': ['Grey', "Why Don't We"],
#  '5GzgEC6pWf1USZsCtkG8yC': ['Paper Planes', 'Elina'],
#  '44V6EzbUSYgyfsNiP0FrlA': ['Visiting Hours', 'Ed Sheeran'],
#  '61Emqg95O9zo1GNOcyxq4Y': ['For Tonight', 'Giveon'],
#  '136J2Jkg8sG7P5wilO9P1R': ['Meant To Be', 'Ber'],
#  '31sSFHIe4NaxltVFOEIcTa': ['working', 'Tate McRae'],
#  '3IpYb4BekvsgmZKwI2ZDu0': ['colorblind', 'Mokita'],
#  '15OCqNPYoLziEAsbVnqRj5': ['Good Without', 'Mimi Webb'],
#  '68z9t6zihQgqzBGtexjTRG': ['Happy For You', 'Lukas Graham'],
#  '0ri0Han4IRJhzvERHOZTMr': ['At My Worst', 'Pink Sweat$'],
#  '0E4Y1XIbs8GrAT1YqVy6dq': ['Afterglow', 'Ed Sheeran'],
#  '2EBnvom1dTybtm75a3Xh1T': ['feel like shit', 'Tate McRae'],
#  '3H3r2nKWa3Yk5gt8xgmsEt': ['This City', 'Sam Fischer'],
#  '4pvb0WLRcMtbPGmtejJJ6y': ['exile (feat. Bon Iver)', 'Taylor Swift'],
#  '6TbkMxKZudkP6Sty7rkLU9': ['Perfectly Imperfect', 'Declan J Donovan'],
#  '3z1DnGBH2uhlDekJr0YVzQ': ['Best Days', 'Alessia Cara'],
#  '5u1n1kITHCxxp8twBcZxWy': ['Holy (feat. Chance The Rapper)', 'Justin Bieber'],
#  '2kJwzbxV2ppxnQoYw4GLBZ': ['If the World Was Ending (feat. Julia Michaels)',
#   'JP Saxe'],
#  '2GjQ5KNXggsIRpx5ZUj2zX': ['Her', 'Anne-Marie'],
#  '5QYnNhTKsN3kE7OaqILA1U': ['First Times', 'Ed Sheeran'],
#  '45Q6RNX1yeHpGZpR0RjpKI': ['Lost', 'Blake Rose'],
#  '45bE4HXI0AwGZXfZtMp8JR': ['you broke me first', 'Tate McRae'],
#  '54fT5TBqwmJKn6NmJR5VKe': ['the author', 'Luz'],
#  '18XlJEroUwFo0tLZxscgXE': ['Lost', 'Maroon 5'],
#  '7GLBqDKAJLCLIsj2GEDkSw': ['nobody else', 'LANY'],
#  '2gA74HvN6NKFrhgzpd5oNE': ['Line By Line (feat. Maren Morris)', 'JP Saxe'],
#  '4y4spB9m0Q6026KfkAvy9Q': ['Lonely (with benny blanco)', 'Justin Bieber'],
#  '7rq1zCf90CnU7OalBLIgNp': ['r u ok', 'Tate McRae'],
#  '0awuNCj9gwJEM0seER22DW': ['CHICKEN TENDIES', 'Clinton Kane'],
#  '19pChrR4hwdINqoOFUo2Hj': ['Keep Your Head Up Princess', 'Anson Seabra'],
#  '5CZ40GBx1sQ9agT82CLQCT': ['traitor', 'Olivia Rodrigo'],
#  '2HnfqILzgKt1CepTlU4oqq': ['Like No One Does', 'Jake Scott'],
#  '4Gt2kh3QbAGU6yquOWn4aW': ['Fake', 'Lauv'],
#  '5inDa3sWj8zqJBOdj7Bjqc': ['Hey Stupid, I Love You', 'JP Saxe'],
#  '0hqJxaNkPQ3sPm1tvfPlAe': ['Cry with you', 'Jeremy Zucker'],
#  '1Ia95g66IhlAJ3qVI4qI8W': ['Slow', 'SHY Martin'],
#  '04NMWz4ctkuILV6mUR2iWp': ['Lie', 'Sasha Alex Sloan'],
#  '0QdePZJfBpRIBautuT4FSx': ['Angels Like You', 'Miley Cyrus'],
#  '6sHxpnCerm9M6A5zaFFNfs': ['Gone', 'Blake Rose'],
#  '6c7N5N7amAOpeMykjlovjI': ['Walked Through Hell', 'Anson Seabra'],
#  '00cBcYOlnHoXX9ver3cmdE': ['A Little Bit Yours', 'JP Saxe'],
#  '6CDzDgIUqeDY5g8ujExx2f': ['Heat Waves', 'Glass Animals'],
#  '4HBZA5flZLE435QTztThqH': ['Stuck with U (with Justin Bieber)',
#   'Ariana Grande'],
#  '2CIYemjFXdmCWpJnfbtrD6': ['New Normal', 'Khalid'],
#  '0Kjkp9SLw8uhBAiSrSgdcB': ['Forever Young', 'Boy In Space'],
#  '5HBDBBr5OV90lubqW8ctJF': ['if we never met', 'John K'],
#  '55vsJO4tLZQ37qzD5QUOmh': ['House With No Mirrors', 'Sasha Alex Sloan'],
#  '3zjw3EZfvgjuR4AQhVlNq7': ['Lovely', 'Fly By Midnight'],
#  '1tUdd0dSQ5ij2XiqlWhlHX': ['Good Stuff', 'Griff'],
#  '5FNS5Vj69AhRGJWjhrAd01': ['Slow Dance (feat. Ava Max)', 'AJ Mitchell'],
#  '5z8uLrYMcUVvzTV28twt44': ['Slow Grenade', 'Ellie Goulding'],
#  '3w1P8nwsVi9vxrGvxYLzAC': ['Hope Is A Heartache', 'LÉON'],
#  '2769RhOZs0ezRncRW1vryp': ['Till Forever Falls Apart', 'Ashe'],
#  '7ce20yLkzuXXLUhzIDoZih': ['Before You Go', 'Lewis Capaldi'],
#  '0ClPIeT6MSgfSgQ9ZrJbAq': ['Cheating on You', 'Charlie Puth'],
#  '2tSDwInMbSGmUySTeUgO5e': ['Love Like That', 'Lauv'],
#  '034KyQEk7IhbLtniVhBErj': ['17', 'Pink Sweat$'],
#  '4f9IfFvBFm7Gsf1IVEudyf': ['lie to me', 'Tate McRae'],
#  '2Ms8MDDtYBw7M3K5F3EqPX': ['Dumb Love', 'Mimi Webb'],
#  '47EWMOElkkbMp5m9SBkx7d': ['IDK You Yet', 'Alexander 23'],
#  '1LdS1ULS9e18oW3M2C1MUj': ["always, i'll care", 'Jeremy Zucker'],
#  '5kcvBnt6DPX3AMEsCx1qDh': ['Happiest Year', 'Jaymes Young'],
#  '4P6g8wuXeR3wznFk7WnI4w': ['Losing Me', 'Gabrielle Aplin'],
#  '7l97ElWmIdVHWUaOeeU5ZC': ['that way', 'Tate McRae'],
#  '5ovVcYo2MvjVydFwFyaaqy': ['I Should Probably Go To Bed', 'Dan + Shay'],
#  '1Srt81FTalOhRw7t7l8Yh8': ['Tattoos Together', 'Lauv'],
#  '6LZ9FO9UsGIcTKbShnfNsG': ['Feels (feat. Khalid)', 'WATTS'],
#  '1hCTxutVVYvggAQcUUUZAT': ['Put A Little Love On Me', 'Niall Horan'],
#  '0cppqb4vQycORHNMxr8DGd': ['Favorite Part Of Me', 'Astrid S'],
#  '3ZBeHiRJUj1vdiU8zzGPgb': ['WYD Now?', 'Sadie Jean'],
#  '4SHJLxcRicQyT42jG95Y5u': ['No Right To Love You', 'Rhys Lewis'],
#  '0E6uWutxRjIDhleURR92do': ['cowboy in LA', 'LANY'],
#  '3Z8FwOEN59mRMxDCtb8N0A': ['Be Kind (with Halsey)', 'Marshmello'],
#  '5RfrZ5Lgr3fdtgnvhh3va8': ["Can't Let You Go", 'Ali Gatie']}

# %%
# As we have limit 100, need do while to get all songs of the play list
# While playlist have next we can get new data
def get_tracks(playlist):
    tracks = playlist['items']
    while playlist['next']:
        playlist = sp.next(playlist)
        tracks.extend(playlist['items'])
    return tracks
first_results = get_tracks(playlist)

# get track list with url uri or ID for each track - ID in this case
audio_feats = []
for x in range(len(first_results)):
    audio_feats.extend(sp.audio_features(tracks=first_results[x]['track']['id']))

# Transform in to Dataframe
data = pd.DataFrame(audio_feats)
data
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.422   0.340    0    -6.577     1       0.0351        0.8770
# 1           0.700   0.613   11    -4.041     1       0.0408        0.3850
# 2           0.392   0.574    7    -9.195     1       0.1700        0.8330
# 3           0.562   0.379    6    -7.625     1       0.2310        0.5260
# 4           0.604   0.366    5    -7.519     1       0.0282        0.5780
# ..            ...     ...  ...       ...   ...          ...           ...
# 125         0.614   0.647    0    -4.681     0       0.0524        0.0687
# 126         0.775   0.410    3    -7.481     1       0.0464        0.7240
# 127         0.634   0.285    9   -14.007     0       0.0807        0.9370
# 128         0.691   0.474   10    -8.742     0       0.0583        0.5690
# 129         0.677   0.454    2    -8.555     0       0.0673        0.8300
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000018    0.1490    0.223   77.213  audio_features
# 1            0.000000    0.0887    0.420   88.084  audio_features
# 2            0.001790    0.1450    0.529   81.112  audio_features
# 3            0.000000    0.1510    0.258  171.848  audio_features
# 4            0.000000    0.1330    0.130  141.981  audio_features
# ..                ...       ...      ...      ...             ...
# 125          0.000000    0.1040    0.368  163.862  audio_features
# 126          0.000026    0.1140    0.298  117.165  audio_features
# 127          0.000359    0.2320    0.203  129.650  audio_features
# 128          0.000626    0.0990    0.381  143.783  audio_features
# 129          0.000086    0.2740    0.273   80.045  audio_features
#
#                          id                                   uri  \
# 0    1is8gU4RVcN4J8xItxWoOY  spotify:track:1is8gU4RVcN4J8xItxWoOY
# 1    7eQHxigpuDJjCG50JyzU8v  spotify:track:7eQHxigpuDJjCG50JyzU8v
# 2    0lx2cLdOt3piJbcaXIV74f  spotify:track:0lx2cLdOt3piJbcaXIV74f
# 3    312zSwwbPU7C3sTmro4Wx9  spotify:track:312zSwwbPU7C3sTmro4Wx9
# 4    0gplL1WMoJ6iYaPgMCL0gX  spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# ..                      ...                                   ...
# 125  1HimGOB6BjOaCQYMIF1xtU  spotify:track:1HimGOB6BjOaCQYMIF1xtU
# 126  0NbDnRbBxUaT27CTgmraSG  spotify:track:0NbDnRbBxUaT27CTgmraSG
# 127  5qNh5WtzMbfpSj2jLlBkoD  spotify:track:5qNh5WtzMbfpSj2jLlBkoD
# 128  2KoHxhRyWxJzA0VafWd5Nk  spotify:track:2KoHxhRyWxJzA0VafWd5Nk
# 129  6LyNmMNe5Xomr3MFL6dS7n  spotify:track:6LyNmMNe5Xomr3MFL6dS7n
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1is8gU4RVcN4...
# 1    https://api.spotify.com/v1/tracks/7eQHxigpuDJj...
# 2    https://api.spotify.com/v1/tracks/0lx2cLdOt3pi...
# 3    https://api.spotify.com/v1/tracks/312zSwwbPU7C...
# 4    https://api.spotify.com/v1/tracks/0gplL1WMoJ6i...
# ..                                                 ...
# 125  https://api.spotify.com/v1/tracks/1HimGOB6BjOa...
# 126  https://api.spotify.com/v1/tracks/0NbDnRbBxUaT...
# 127  https://api.spotify.com/v1/tracks/5qNh5WtzMbfp...
# 128  https://api.spotify.com/v1/tracks/2KoHxhRyWxJz...
# 129  https://api.spotify.com/v1/tracks/6LyNmMNe5Xom...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1is8...       204094
# 1    https://api.spotify.com/v1/audio-analysis/7eQH...       191250
# 2    https://api.spotify.com/v1/audio-analysis/0lx2...       214707
# 3    https://api.spotify.com/v1/audio-analysis/312z...       204989
# 4    https://api.spotify.com/v1/audio-analysis/0gpl...       224695
# ..                                                 ...          ...
# 125  https://api.spotify.com/v1/audio-analysis/1Him...       184665
# 126  https://api.spotify.com/v1/audio-analysis/0NbD...       186733
# 127  https://api.spotify.com/v1/audio-analysis/5qNh...       245897
# 128  https://api.spotify.com/v1/audio-analysis/2KoH...       179917
# 129  https://api.spotify.com/v1/audio-analysis/6LyN...       210406
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 125               4
# 126               4
# 127               4
# 128               4
# 129               4
#
# [130 rows x 18 columns]

# %% [markdown]
# # Apply clustering

# %% [markdown]
# ## With scaled data

# %%
# fast lock to our data
plt.scatter(data.iloc[:,0],data.iloc[:,1], data.iloc[:,2],data.iloc[:,3])

# %%
# get the main columns for  clustering
data_selected = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','tempo']]
data_selected
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.422   0.340    -6.577       0.0351        0.8770
# 1           0.700   0.613    -4.041       0.0408        0.3850
# 2           0.392   0.574    -9.195       0.1700        0.8330
# 3           0.562   0.379    -7.625       0.2310        0.5260
# 4           0.604   0.366    -7.519       0.0282        0.5780
# ..            ...     ...       ...          ...           ...
# 125         0.614   0.647    -4.681       0.0524        0.0687
# 126         0.775   0.410    -7.481       0.0464        0.7240
# 127         0.634   0.285   -14.007       0.0807        0.9370
# 128         0.691   0.474    -8.742       0.0583        0.5690
# 129         0.677   0.454    -8.555       0.0673        0.8300
#
#      instrumentalness  liveness  valence    tempo
# 0            0.000018    0.1490    0.223   77.213
# 1            0.000000    0.0887    0.420   88.084
# 2            0.001790    0.1450    0.529   81.112
# 3            0.000000    0.1510    0.258  171.848
# 4            0.000000    0.1330    0.130  141.981
# ..                ...       ...      ...      ...
# 125          0.000000    0.1040    0.368  163.862
# 126          0.000026    0.1140    0.298  117.165
# 127          0.000359    0.2320    0.203  129.650
# 128          0.000626    0.0990    0.381  143.783
# 129          0.000086    0.2740    0.273   80.045
#
# [130 rows x 9 columns]

# %%
# Scale data
data_scaled = fn.st_scaler (data_selected)
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.325051 -0.725265  0.645667    -0.478603      1.261071
# 1        0.904653  1.225447  1.683378    -0.393047     -0.397305
# 2       -1.565667  0.946774 -0.425597     1.546210      1.112761
# 3       -0.202179 -0.446592  0.216834     2.461804      0.077961
# 4        0.134683 -0.539483  0.260208    -0.582170      0.253237
# ..            ...       ...       ...          ...           ...
# 125      0.214888  1.468393  1.421495    -0.218934     -1.463453
# 126      1.506191 -0.225082  0.275758    -0.308993      0.745356
# 127      0.375298 -1.118265 -2.394629     0.205841      1.463312
# 128      0.832468  0.232228 -0.240233    -0.130377      0.222900
# 129      0.720181  0.089318 -0.163715     0.004711      1.102649
#
#      instrumentalness  liveness   valence     tempo
# 0           -0.133938  0.084918 -0.628850 -1.262785
# 1           -0.136378 -0.634961  0.549688 -0.903305
# 2            0.110345  0.037165  1.201773 -1.133854
# 3           -0.136378  0.108795 -0.419465  1.866586
# 4           -0.136378 -0.106095 -1.185216  0.878950
# ..                ...       ...       ...       ...
# 125         -0.136378 -0.452305  0.238602  1.602507
# 126         -0.132767 -0.332922 -0.180168  0.058339
# 127         -0.086895  1.075796 -0.748498  0.471191
# 128         -0.050094 -0.511996  0.316374  0.938538
# 129         -0.124593  1.577204 -0.329728 -1.169137
#
# [130 rows x 9 columns]

# %%
# visualise data to check the shape has not changed through scaling 
data_selected.hist(bins=15,figsize=(15,15));

# %%
data_scaled.hist(bins=15,figsize=(15,15));

# %%
# Use methos KMeans in scaled dataframe - use consistent random state
model = KMeans(n_clusters=10,random_state=5)
cluster_scaled = model.fit(data_scaled)

# %%
# Show the coordinates of each cluster
cluster_scaled.cluster_centers_
# Out:
# array([[ 0.17419145, -0.33067624,  0.25517679, -0.34012391,  0.46221901,
#         -0.1192627 , -0.43850961, -0.5217865 ,  0.41512757],
#        [ 0.21087789, -0.72169196, -0.80453846, -0.28240396,  0.6712014 ,
#         -0.13345854, -0.06814794,  0.91333462,  0.66055844],
#        [ 0.07051885,  0.13831579,  0.21794465, -0.05833012, -0.01993322,
#         -0.09514961,  2.52459217, -0.21174639,  0.3749613 ],
#        [ 0.33519589, -0.9682105 , -1.46494512, -0.36903154,  1.28466584,
#         10.55955046, -0.21353922, -0.82028749, -1.2700271 ],
#        [-1.46193451,  0.17887481,  0.39221368, -0.38704322, -0.31681342,
#         -0.12641788, -0.44323186, -0.71543547, -0.90751583],
#        [ 0.39815695,  1.55306681,  0.91831182, -0.11701817, -1.07165107,
#          0.13468827, -0.32444591,  0.36952766,  0.08362147],
#        [-0.34755057, -0.52429849, -1.13375534,  2.51621391,  0.65308397,
#         -0.1055124 , -0.24338494,  0.37522592, -0.25076177],
#        [-0.94993764, -1.16333666, -1.53180079, -0.22355262,  0.87551669,
#         -0.12887207, -0.12023692, -0.83800468, -0.11484676],
#        [ 1.02897057,  1.48268398, -0.28156186,  4.89337998, -0.99728705,
#         -0.13601113, -0.68152007,  1.74916525, -0.86006905],
#        [ 1.12872575,  0.04197961,  0.50528877, -0.28385132, -0.70680784,
#         -0.13406138, -0.27039531,  0.80132435, -0.4547591 ]])

# %%
# Show the cluster of each row
cluster_scaled.labels_
# Out:
# array([4, 5, 6, 6, 0, 7, 9, 7, 0, 0, 1, 5, 2, 0, 0, 6, 4, 4, 7, 9, 2, 0,
#        9, 2, 2, 1, 7, 1, 0, 4, 1, 9, 5, 2, 5, 9, 2, 0, 9, 4, 0, 7, 8, 6,
#        0, 1, 5, 0, 7, 5, 7, 9, 0, 2, 5, 6, 4, 6, 5, 8, 1, 0, 9, 5, 4, 7,
#        0, 9, 2, 4, 1, 9, 1, 5, 0, 9, 5, 2, 4, 4, 9, 9, 0, 2, 4, 3, 1, 7,
#        0, 2, 0, 9, 2, 0, 0, 6, 0, 1, 5, 0, 5, 5, 5, 1, 4, 1, 1, 1, 0, 5,
#        2, 9, 7, 7, 0, 5, 5, 5, 9, 6, 4, 4, 0, 7, 4, 5, 0, 7, 0, 2])

# %%
#add cluster back into scaled data
data_scaled['cluster_no'] = cluster_scaled.labels_
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.325051 -0.725265  0.645667    -0.478603      1.261071
# 1        0.904653  1.225447  1.683378    -0.393047     -0.397305
# 2       -1.565667  0.946774 -0.425597     1.546210      1.112761
# 3       -0.202179 -0.446592  0.216834     2.461804      0.077961
# 4        0.134683 -0.539483  0.260208    -0.582170      0.253237
# ..            ...       ...       ...          ...           ...
# 125      0.214888  1.468393  1.421495    -0.218934     -1.463453
# 126      1.506191 -0.225082  0.275758    -0.308993      0.745356
# 127      0.375298 -1.118265 -2.394629     0.205841      1.463312
# 128      0.832468  0.232228 -0.240233    -0.130377      0.222900
# 129      0.720181  0.089318 -0.163715     0.004711      1.102649
#
#      instrumentalness  liveness   valence     tempo  cluster_no
# 0           -0.133938  0.084918 -0.628850 -1.262785           4
# 1           -0.136378 -0.634961  0.549688 -0.903305           5
# 2            0.110345  0.037165  1.201773 -1.133854           6
# 3           -0.136378  0.108795 -0.419465  1.866586           6
# 4           -0.136378 -0.106095 -1.185216  0.878950           0
# ..                ...       ...       ...       ...         ...
# 125         -0.136378 -0.452305  0.238602  1.602507           5
# 126         -0.132767 -0.332922 -0.180168  0.058339           0
# 127         -0.086895  1.075796 -0.748498  0.471191           7
# 128         -0.050094 -0.511996  0.316374  0.938538           0
# 129         -0.124593  1.577204 -0.329728 -1.169137           2
#
# [130 rows x 10 columns]

# %%
data_scaled['cluster_no'].value_counts()
# Out:
# 0    27
# 5    20
# 9    16
# 4    15
# 1    14
# 2    14
# 7    13
# 6     8
# 8     2
# 3     1
# Name: cluster_no, dtype: int64

# %% [markdown]
# ## With normal data

# %%
# New Dataframe to keep the original
data_normal = data_selected

# %%
# Use methos KMeans in normal dataframe - use consistent random state
cluster_normal = model.fit(data_normal)

# %%
# Show the coordinates of each cluster
cluster_normal.cluster_centers_
# Out:
# array([[ 5.12520000e-01,  3.81120000e-01, -9.17788000e+00,
#          7.34760000e-02,  6.45580000e-01,  3.19060840e-03,
#          1.22668000e-01,  3.02092000e-01,  7.82661200e+01],
#        [ 6.27714286e-01,  4.31357143e-01, -7.58650000e+00,
#          4.44500000e-02,  4.48000000e-01,  2.07892857e-04,
#          1.41828571e-01,  2.81000000e-01,  1.30781643e+02],
#        [ 4.84900000e-01,  3.54800000e-01, -9.15600000e+00,
#          9.79000000e-02,  5.59400000e-01,  4.10466000e-04,
#          1.86900000e-01,  3.36120000e-01,  1.73994300e+02],
#        [ 6.56571429e-01,  4.63928571e-01, -8.16764286e+00,
#          4.17785714e-02,  5.61625000e-01,  7.54942857e-04,
#          1.33371429e-01,  3.95214286e-01,  1.20924786e+02],
#        [ 5.77769231e-01,  5.32615385e-01, -7.11707692e+00,
#          5.30615385e-02,  4.16350769e-01,  2.19230769e-03,
#          1.03746154e-01,  3.27376923e-01,  9.70196923e+01],
#        [ 6.12600000e-01,  4.67100000e-01, -7.77495000e+00,
#          5.63500000e-02,  4.81165000e-01,  6.10455000e-05,
#          1.43220000e-01,  3.06910000e-01,  1.43317550e+02],
#        [ 2.86000000e-01,  4.45000000e-01, -8.08700000e+00,
#          3.47000000e-02,  3.55000000e-01,  0.00000000e+00,
#          1.14000000e-01,  2.78000000e-01,  5.08270000e+01],
#        [ 6.53571429e-01,  3.73928571e-01, -8.34700000e+00,
#          6.51214286e-02,  5.55528571e-01,  2.90650000e-05,
#          1.65557143e-01,  3.08128571e-01,  1.06653214e+02],
#        [ 6.24461538e-01,  5.45384615e-01, -6.99007692e+00,
#          1.21046154e-01,  2.79615385e-01,  7.81015385e-05,
#          1.66453846e-01,  3.90207692e-01,  8.92913077e+01],
#        [ 5.63000000e-01,  4.58166667e-01, -9.12266667e+00,
#          5.80500000e-02,  4.50283333e-01,  2.22850000e-05,
#          1.41333333e-01,  3.69333333e-01,  1.58207833e+02]])

# %%
# Show the cluster of each row
cluster_normal.labels_
# Out:
# array([0, 8, 0, 2, 5, 0, 4, 0, 1, 5, 3, 4, 3, 1, 1, 0, 6, 0, 2, 5, 1, 7,
#        8, 5, 7, 9, 2, 5, 5, 0, 2, 7, 5, 8, 1, 8, 7, 5, 0, 0, 7, 0, 8, 0,
#        3, 4, 4, 3, 0, 5, 9, 0, 0, 5, 4, 0, 4, 7, 0, 8, 9, 5, 7, 3, 5, 0,
#        8, 0, 2, 8, 3, 7, 3, 9, 5, 1, 5, 2, 4, 7, 3, 0, 1, 5, 0, 0, 7, 7,
#        1, 7, 1, 3, 2, 4, 3, 2, 9, 2, 4, 1, 1, 8, 1, 3, 4, 5, 1, 3, 5, 4,
#        8, 7, 0, 7, 4, 8, 3, 5, 4, 8, 8, 0, 2, 5, 0, 9, 3, 1, 5, 0])

# %%
#add cluster back into normal data
data_normal['cluster_no'] = cluster_normal.labels_
data_normal
# Out:
# C:\Users\Agus\AppData\Local\Temp/ipykernel_5844/263779458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_normal['cluster_no'] = cluster_normal.labels_
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.422   0.340    -6.577       0.0351        0.8770
# 1           0.700   0.613    -4.041       0.0408        0.3850
# 2           0.392   0.574    -9.195       0.1700        0.8330
# 3           0.562   0.379    -7.625       0.2310        0.5260
# 4           0.604   0.366    -7.519       0.0282        0.5780
# ..            ...     ...       ...          ...           ...
# 125         0.614   0.647    -4.681       0.0524        0.0687
# 126         0.775   0.410    -7.481       0.0464        0.7240
# 127         0.634   0.285   -14.007       0.0807        0.9370
# 128         0.691   0.474    -8.742       0.0583        0.5690
# 129         0.677   0.454    -8.555       0.0673        0.8300
#
#      instrumentalness  liveness  valence    tempo  cluster_no
# 0            0.000018    0.1490    0.223   77.213           0
# 1            0.000000    0.0887    0.420   88.084           8
# 2            0.001790    0.1450    0.529   81.112           0
# 3            0.000000    0.1510    0.258  171.848           2
# 4            0.000000    0.1330    0.130  141.981           5
# ..                ...       ...      ...      ...         ...
# 125          0.000000    0.1040    0.368  163.862           9
# 126          0.000026    0.1140    0.298  117.165           3
# 127          0.000359    0.2320    0.203  129.650           1
# 128          0.000626    0.0990    0.381  143.783           5
# 129          0.000086    0.2740    0.273   80.045           0
#
# [130 rows x 10 columns]

# %%
data_normal['cluster_no'].value_counts()
# Out:
# 0    25
# 5    20
# 1    14
# 3    14
# 7    14
# 8    13
# 4    13
# 2    10
# 9     6
# 6     1
# Name: cluster_no, dtype: int64

# %% [markdown]
# # Getting the best K

# %%
###  3 metrics : inertia, distortion, silouhette score

# %%
# lets remove the cluster from my df to make the model again
data_scaled = data_scaled.drop('cluster_no',axis=1)
data_scaled
# Out:
#      danceability    energy  loudness  speechiness  acousticness  \
# 0       -1.325051 -0.725265  0.645667    -0.478603      1.261071
# 1        0.904653  1.225447  1.683378    -0.393047     -0.397305
# 2       -1.565667  0.946774 -0.425597     1.546210      1.112761
# 3       -0.202179 -0.446592  0.216834     2.461804      0.077961
# 4        0.134683 -0.539483  0.260208    -0.582170      0.253237
# ..            ...       ...       ...          ...           ...
# 125      0.214888  1.468393  1.421495    -0.218934     -1.463453
# 126      1.506191 -0.225082  0.275758    -0.308993      0.745356
# 127      0.375298 -1.118265 -2.394629     0.205841      1.463312
# 128      0.832468  0.232228 -0.240233    -0.130377      0.222900
# 129      0.720181  0.089318 -0.163715     0.004711      1.102649
#
#      instrumentalness  liveness   valence     tempo
# 0           -0.133938  0.084918 -0.628850 -1.262785
# 1           -0.136378 -0.634961  0.549688 -0.903305
# 2            0.110345  0.037165  1.201773 -1.133854
# 3           -0.136378  0.108795 -0.419465  1.866586
# 4           -0.136378 -0.106095 -1.185216  0.878950
# ..                ...       ...       ...       ...
# 125         -0.136378 -0.452305  0.238602  1.602507
# 126         -0.132767 -0.332922 -0.180168  0.058339
# 127         -0.086895  1.075796 -0.748498  0.471191
# 128         -0.050094 -0.511996  0.316374  0.938538
# 129         -0.124593  1.577204 -0.329728 -1.169137
#
# [130 rows x 9 columns]

# %%
K = range(8,18)
inertia = []
for k in K:
    best_model = KMeans(n_clusters=k,random_state=5)
    best_model.fit(data_scaled)
    inertia.append(best_model.inertia_)

# %%
#plot the resulting inertia - elbow 
plt.figure(figsize=(16,8))
plt.plot(K,inertia,'bx-')
plt.xlabel('k=noofclusters')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('elbow method inertia to find optimal K');

# %%
K = range(5,18)
sil = []
for k in K:
    best_model = KMeans(n_clusters=k,random_state=5)
    best_model.fit(data_scaled)
    sil.append(silhouette_score(data_scaled,best_model.predict(data_scaled)))

# %%
#plot the resulting silhouette 
plt.figure(figsize=(16,8))
plt.plot(K,sil,'bo-')
plt.xlabel('k=noofclusters')
plt.ylabel('silhouette')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('silhouette score');

# %%
# watching the plot, 11 seems the best k
# Try again with scaled data and best k
model=KMeans(n_clusters=11, random_state=5)
cluster_best=model.fit(data_scaled)
data_scaled['cluster_final'] = cluster_best.labels_

# %%
data_scaled['cluster_final'].value_counts()
# Out:
# 0     23
# 5     21
# 10    18
# 7     16
# 1     14
# 4     13
# 3      9
# 6      7
# 9      4
# 8      4
# 2      1
# Name: cluster_final, dtype: int64

# %%
data_scaled.head(1)
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -1.325051 -0.725265  0.645667    -0.478603      1.261071
#
#    instrumentalness  liveness  valence     tempo  cluster_final
# 0         -0.133938  0.084918 -0.62885 -1.262785              1

# %%
def spotify_display(song_name_id):
        display(IFrame(src=f"https://open.spotify.com/embed/track/{song_name_id}",
                        width="320",
                        height="80",
                        frameborder="0",
                        allowtransparency="true",
                        allow="encrypted-media",))

# %% [markdown]
# # Show results with GUI (Tkinter)

# %%
# Create a new window
def try_again(window):
    window.destroy()
    # line 177
    create()

# Close window
def close(window):
    window.destroy()

# Show the results after compare input and top[song] when the match is positive
# Check has the Dataframe with 1 positive result
def but_yes_top(window,check,positionRight,positionDown):
    window.destroy()
    # Create a window
    window = tk.Tk()

    #Change size os window
    window.geometry("+{}+{}".format(positionRight, positionDown))
    
    # Create a new dataframe without result to avoid repeat
    result = top.drop(labels=check.index, axis=0)

    # Create a new dataframe with a random sample to share
    result = result.sample()
    song_res = result['Song'].item()
    artist_res = result['Artist'].item()
    
    # Show the results
    res1 = tk.Label(window, text = 'Nice choice, your song is in the top 100, maybe you like this one too')
    res1.pack(fill = tk.X)
    res2 = tk.Label(window, text = f'{song_res} - by - {artist_res}')
    res2.pack(fill = tk.X)
    space = tk.Label(window, text = "   ")
    space.pack(fill = tk.X)
    
    #  Ask for Try Again
    label_no = tk.Label(window, text = 'Do you want to try again?')
    label_no.pack(fill = tk.X)
    # Line 2
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()
    
def but_yes_play(window,match,positionRight,positionDown):    
    window.destroy()
    # Create a window
    window = tk.Tk()

    # Positions the window in the center of the page.
    window.geometry("+{}+{}".format(positionRight, positionDown))
    
    track_id = sp.search(q='track:' + match[0].lower(), type='track', limit=1)
    track_id
    
    # x is the id that we are looking for
    x = track_id["tracks"]['items'][0]['id']
    x
    
    # audio_feature is a dataframe with the results 
    audio_feat=pd.DataFrame(sp.audio_features(tracks=x))
    audio_feat
    
    # get the main columns for  clustering
    audio_feat = audio_feat[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence','tempo']]
    audio_feat
    
    # fit without column cluster
    scaler=StandardScaler()
    model = scaler.fit(data_scaled.drop('cluster_final',axis=1)).transform(audio_feat)
    model
    
    # dataframe with audio feature scaled
    audio_scaled = pd.DataFrame(model, index=audio_feat.index, columns=audio_feat.columns)
    audio_scaled
    
    # predict the cluster and get the number
    model=KMeans(n_clusters=11, random_state=5)
    cluster_best=model.fit(data_scaled.drop('cluster_final',axis=1))
    pred = cluster_best.predict(audio_scaled)
    pred[0]
    
    # use new cluster to get a index of random song with the same cluster
    samp = data_scaled[data_scaled.cluster_final==pred[0]].sample(1).index.item()
    samp
    
    # use that index to get the id of new song
    data_samp = data[samp:samp+1]
    data_samp
    
    #use id to get the song and the artist name
    song_artist = ''
    for key, value in list_info.items():
        if key == data_samp['id'].item():
            song_artist = value
    
    if len(song_artist) != 0:           
        label_no = tk.Label(window, text = f'Nice choice, your song: {match[0].upper()} - by - {match[1]} with cluster {pred[0]},\n is in my playlist, maybe you like this one too. \n {song_artist[0].upper()} - by - {song_artist[1]} with cluster {pred[0]} \n\n Do you want to try again?')
        label_no.pack(fill = tk.X)
        # display of song from spotify
        #spotify_display(song_artist[0])-------------------------------------------------------------------------------
    else:
        label_no = tk.Label(window, text = f'Nice choice, your song is in my playlist, \n maybe you like this one too. \n {song_artist[0].upper()} - by - {song_artist[1]} \n\n Do you want to try again?')
        label_no.pack(fill = tk.X)
        
    # Line 2
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    # Line 7
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()
    
def but_no_top(window,songs,positionRight,positionDown):
    window.destroy()
    # Create a window
    window = tk.Tk()

    # Positions the window in the center of the page.
    window.geometry("+{}+{}".format(positionRight, positionDown))

    label_no = tk.Label(window, text = f'Sorry, your song is not in the top 100. \n Do you want to try again? \n Do you want search in my playlist?')
    label_no.pack(fill = tk.X)
    # Line 2
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    # Line 69
    button_search_play = tk.Button(window, text = 'Search in play list', command = lambda: get_data_play(window,songs,positionRight,positionDown))
    button_search_play.pack()
    # Line 7
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()

def but_no_play(window,positionRight,positionDown):
    window.destroy()
    # Create a window
    window = tk.Tk()

    # Positions the window in the center of the page.
    window.geometry("+{}+{}".format(positionRight, positionDown))

    label_no = tk.Label(window, text = f'Sorry, your song is not in my playlist. \n Do you want to try again?')
    label_no.pack(fill = tk.X)
    
    # Line 2
    button_retry = tk.Button(window, text = 'Try again', command = lambda: try_again(window))
    button_retry.pack()
    # Line 7
    button_close = tk.Button(window, text = 'Close', command = lambda: close(window))
    button_close.pack()
    
# Search matches in own play list
def get_data_play(window,songs,positionRight,positionDown):
    window.destroy()
    # Create a window
    window = tk.Tk()

    # Positions the window in the center of the page.
    window.geometry("+{}+{}".format(positionRight, positionDown))
    
    #check if song is in the play list
    res = 0
    match = ''
    for key, value in list_info.items():
        if fuzz.token_sort_ratio(value[0],songs) > res:
            res = fuzz.token_set_ratio(value[0],songs)
            match = value

    ask = tk.Label(window, text = f'Did you mean this song? \n  {match[0].upper()} - by - {match[1]}')
    ask.pack(fill = tk.X)
    
    # Line 12
    button_yes_play = tk.Button(window, text = 'Yes', command = lambda: but_yes_play(window,match,positionRight,positionDown))
    button_yes_play.pack()
    # Line 48
    button_no_play = tk.Button(window, text = 'No', command = lambda: but_no_play(window,positionRight,positionDown))
    button_no_play.pack()

# Search matches in top 100
def get_data_top(input_song,window,positionRight,positionDown):
    # Transform to string
    songs = input_song.get()
    if len(songs) == 0:
        messagebox.showwarning('Error','You need to enter at least one song.')
    else:
        window.destroy()
        # Create a window
        window = tk.Tk()

        # Positions the window in the center of the page.
        window.geometry("+{}+{}".format(positionRight, positionDown))
        
        # fuzz token compare the input with the songs of the dataframe
        # we save in -best- the best result
        res = 0
        for x in top['Song']:
            if fuzz.token_sort_ratio(x,songs) > res:
                res = fuzz.token_set_ratio(x,songs)
                best = x

        # get data from best result
        check = top[(top['Song']==best)]
        artist = check['Artist'].item()

        # Show the results
        window.geometry("")
        ask = tk.Label(window, text = f'Did you mean this song? \n  {best} - by - {artist}')
        ask.pack(fill = tk.X)
    
        # Line 12
        button_yes_top = tk.Button(window, text = 'Yes', command = lambda: but_yes_top(window,check,positionRight,positionDown))
        button_yes_top.pack()
        # Line 48
        button_no_top = tk.Button(window, text = 'No', command = lambda: but_no_top(window,songs,positionRight,positionDown))
        button_no_top.pack()
        space = tk.Label(window, text = "   ")
        space.pack(fill = tk.X)

# Create the main window
def create():   
    # Create a window
    window = tk.Tk()
    
    # Center window
    # Gets the requested values of the height and widht.
    windowWidth = window.winfo_reqwidth()
    windowHeight = window.winfo_reqheight()
 
    # Gets both half the screen width/height and window width/height
    positionRight = int(window.winfo_screenwidth()/2 - windowWidth/2)
    positionDown = int(window.winfo_screenheight()/2 - windowHeight/2)
 
    # Positions the window in the center of the page.
    window.geometry("+{}+{}".format(positionRight, positionDown))

    # Title
    title = tk.Label(window, text = 'Enter a song and/or an artist to see if its in the top 100', bg = 'gray51')
    title.pack(fill = tk.X)

    #Take song
    title_song = tk.Label(window, text = 'Enter a song')
    title_song.pack(fill = tk.X)
    input_song = tk.Entry(window)
    input_song.pack()

    # Line 140
    button_search_top = tk.Button(window, text = 'Search in top100', command = lambda: get_data_top(input_song,window,positionRight,positionDown))
    button_search_top.pack()
    space = tk.Label(window, text = "   ")
    space.pack(fill = tk.X)
    
    #That comand open the window
    window.mainloop()

# %%
create()
